# %% [markdown]
# ## Import Library Files

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer=SentimentIntensityAnalyzer()

# %matplotlib inline

# %% [markdown]
# ## News API configuration

# %%
api_key=os.getenv("NEWS_API")
from newsapi import NewsApiClient
newsapi=NewsApiClient(api_key=api_key)

# %% [markdown]
# ## Fetch the Bitcoin news articles

# %%
coin_headlines = newsapi.get_top_headlines(q="bitcoin", language="en", country="us")
coin_headlines
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %% [markdown]
# **News API with function "get_top_headlines" with country as US did not return any results, hence used get_everything function and discarded country to get details about bitcoin**

# %%
bitcoin_headlines=newsapi.get_everything(q="bitcoin",
                                         language="en",
                                         page_size=100,
                                         sort_by="relevancy")
bitcoin_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 3939,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'PayPal to let you buy and sell cryptocurrencies in the US',
#    'description': 'PayPal has partnered with cryptocurrency company Paxos to launch a new service. PayPal users in the U.S. will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon. PayPal plans to support Bitcoin, Ethereum, Bitcoin Cash and Lite…',
#    'url': 'http://techcrunch.com/2020/10/21/paypal-to-let-you-buy-and-sell-cryptocurrencies-in-the-us/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/07/GettyImages-887657568.jpg?w=600',
#    'publishedAt': '2020-10-21T13:28:15Z',
#    'content': 'PayPal has partnered with cryptocurrency company Paxos to launch a new service. PayPal users in the U.S. will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon.\r\nPay… [+2069 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Zack Whittaker',
#    'title': 'DOJ says it seized over $1 billion in bitcoin from the Silk Road drugs marketplace',
#    'description': 'Two days ago, about $1 billion worth of bitcoin that had sat dormant since the seizure of the Silk Road marketplace in 2013, one of the biggest underground drug websites on the dark web, suddenly changed hands. Who took it? Mystery over. It was the U.S. gover…',
#    'url': 'http://techcrunch.com/2020/11/05/justice-department-silk-road-billion-bitcoin/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/11/GettyImages-887657568.jpg?w=600',
#    'publishedAt': '2020-11-05T17:17:41Z',
#    'content': 'Two days ago, about $1 billion worth of bitcoin that had sat dormant since the seizure of the Silk Road marketplace in 2013, one of the biggest underground drug websites on the dark web, suddenly cha… [+1297 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Nick Statt',
#    'title': 'PayPal and Venmo will offer and accept cryptocurrency for all online payments',
#    'description': 'PayPal is joining the cryptocurrency industry with support for bitcoin and other digital currencies, making the digital payments company one of the most significant adopters of the technology to date. PayPal plans to extend support to its money-sending app Ve…',
#    'url': 'https://www.theverge.com/2020/10/21/21527288/paypal-cryptocurrency-support-buy-sell-venmo-bitcoin',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpbAVPi6j4xmC2Ug=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13546110/acastro_181126_1777_bitcoin_0001.jpg',
#    'publishedAt': '2020-10-21T19:49:27Z',
#    'content': 'PayPal is rolling out cryptocurrency support later this year\r\nIllustration by Alex Castro / The Verge\r\nPayPal on Wednesday announced it would begin supporting cryptocurrencies for the first time, all… [+2172 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'John Biggs',
#    'title': 'Bitcoin Mixer Designed to Bypass Money Laundering Laws Fined $60 Million for Bypassing Money Laundering Laws',
#    'description': 'The Financial Crimes Enforcement Network (FinCEN) has assessed a civil penalty of $60 million from Larry Dean Harmon, the founder of “bitcoin mixers” Helix and Coin Ninja. The penalty is the first of its kind in the United States.Read more...',
#    'url': 'https://gizmodo.com/bitcoin-mixer-designed-to-bypass-money-laundering-laws-1845424354',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/jhxr5xvmk7xprthwguhd.jpg',
#    'publishedAt': '2020-10-20T15:40:00Z',
#    'content': 'The Financial Crimes Enforcement Network (FinCEN) has assessed a civil penalty of $60 million from Larry Dean Harmon, the founder of bitcoin mixers Helix and Coin Ninja. The penalty is the first of i… [+1806 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Engadget',
#    'title': 'The Morning After: Xbox Series X and Series S reviews are in',
#    'description': '2018’s jokes are 2020’s reality. I’m speaking, of course, about Tesla Tequila. Previously featured in an April Fool’s tweet from Elon Musk (pre-SEC settlement era), “Teslaquila” is now an actual drink you can buy. While Tesla didn’t go with the one-word name …',
#    'url': 'https://www.engadget.com/xbox-series-review-tma-121501125.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-11%2F3adb5c41-2027-11eb-afdf-fe7140242bc5&client=amp-blogside-v2&signature=b7fc020c5418b26530a7a36da7e311c72d2e947e',
#    'publishedAt': '2020-11-06T12:15:01Z',
#    'content': '2018’s jokes are 2020’s reality. I’m speaking, of course, about Tesla Tequila. Previously featured in an April Fool’s tweet from Elon Musk (pre-SEC settlement era), “Teslaquila” is now an actual drin… [+2034 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': "'Individual X' stole $1 billion in crypto from Silk Road. U.S. officials just seized it.",
#    'description': 'The U.S. government is trying to seize what "Individual X" had already stolen. Specifically, that would be a gargantuan amount of cryptocurrency.\xa0\nIn a surprise reveal to a mystery that\'s bedeviled the cryptocurrency community for years, the Department of Jus…',
#    'url': 'https://mashable.com/article/hacker-stole-billion-cryptocurrency-silk-road-seized-us-government/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F11%252F05%252F78%252F13ff2cff204c4c35a7eb521ada5908db.29c15.jpg%252F1200x630.jpg?signature=kaXbXXJn3D1YQeYhgTdhZjUbjAo=',
#    'publishedAt': '2020-11-05T20:17:33Z',
#    'content': 'The U.S. government is trying to seize what "Individual X" had already stolen. Specifically, that would be a gargantuan amount of cryptocurrency.\xa0\r\nIn a surprise reveal to a mystery that\'s bedeviled … [+2570 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Bitcoin hits $14,000 for the first time since early 2018',
#    'description': 'Bitcoin hit a low of $3,200 in late 2018.',
#    'url': 'https://arstechnica.com/tech-policy/2020/10/bitcoin-hits-14000-for-the-first-time-since-early-2018/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2017/08/GettyImages-510365916-760x380.jpg',
#    'publishedAt': '2020-10-31T19:15:10Z',
#    'content': '4 with 4 posters participating\r\nThe price of one bitcoin rose above $14,000 on Saturday morning. It was the first time the virtual currency reached that level since January 2018. As I write this, the… [+2653 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'John Biggs',
#    'title': 'PayPal’s Big Crypto Move Is All Hype',
#    'description': 'Cryptocurrencies like bitcoin are a fun way to skirt money-laundering laws and pay for drugs, but, according to reporting by Reuters, it appears you’ll now be able to use it to pay for Beanie Babies and fake Rolexes. That’s right: PayPal is getting into the c…',
#    'url': 'https://gizmodo.com/paypal-s-big-crypto-move-is-all-hype-1845436095',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/mxpjt0z34vraze1ue8qk.jpg',
#    'publishedAt': '2020-10-21T13:49:00Z',
#    'content': 'Cryptocurrencies like bitcoin are a fun way to skirt money-laundering laws and pay for drugs, but, according to reporting by Reuters, it appears youll now be able to use it to pay for Beanie Babies a… [+3888 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'John Biggs',
#    'title': "The DOJ Seized Over a Billion Dollars From Silk Road's Bitcoin Coffers",
#    'description': 'A $1 billion transaction that flowed out of a dormant bitcoin wallet allegedly belonging to Silk Road founder Ross Ulbricht made waves in the crypto world this week, causing some to suspect the founder himself was making moves from prison. No such luck, howev…',
#    'url': 'https://gizmodo.com/the-doj-seized-over-a-billion-dollars-from-silk-roads-b-1845596546',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/iaczpijvjsrrwivf1dg0.jpg',
#    'publishedAt': '2020-11-06T19:20:00Z',
#    'content': 'A $1 billion transaction that flowed out of a dormant bitcoin wallet allegedly belonging to Silk Road founder Ross Ulbricht made waves in the crypto world this week, causing some to suspect the found… [+2022 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Microsoft engineer gets nine years for stealing $10M from Microsoft',
#    'description': 'The defendant tried—and failed—to use bitcoin to cover his tracks.',
#    'url': 'https://arstechnica.com/tech-policy/2020/11/microsoft-engineer-gets-nine-years-for-stealing-10m-from-microsoft/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2014/09/microsoft-640x215.jpg',
#    'publishedAt': '2020-11-10T21:00:12Z',
#    'content': "1 with 1 posters participating\r\nA former Microsoft software engineer from Ukraine has been sentenced to nine years in prison for stealing more than $10 million in store credit from Microsoft's online… [+3119 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'With Instagram, hashtags and bitcoin, young Nigerians boost anti-police protests - Reuters India',
#    'description': 'With Instagram, hashtags and bitcoin, young Nigerians boost anti-police protests\xa0\xa0Reuters India',
#    'url': 'https://in.reuters.com/article/nigeria-protests-police-activists-idINKBN274267',
#    'urlToImage': None,
#    'publishedAt': '2020-10-19T15:57:00Z',
#    'content': 'World News\r\nAlexis Akwagyiram\r\nLAGOS (Reuters) - Ozioma Egemasi says Nigerian police slapped, whipped and struck him with the butt of a pistol when he refused to pay them a bribe. Then he heard them … [+6412 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'With Instagram, hashtags and bitcoin, young Nigerians boost anti-police protests - Reuters.com',
#    'description': 'With Instagram, hashtags and bitcoin, young Nigerians boost anti-police protests\xa0\xa0Reuters.com',
#    'url': 'https://www.reuters.com/article/us-nigeria-protests-police-activists-idUSKBN27418O',
#    'urlToImage': None,
#    'publishedAt': '2020-10-19T10:25:00Z',
#    'content': 'Emerging Markets\r\nAlexis Akwagyiram\r\nLAGOS (Reuters) - Ozioma Egemasi says Nigerian police slapped, whipped and struck him with the butt of a pistol when he refused to pay them a bribe. Then he heard… [+5721 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': "Satoshi Nakamoto's Bitcoin White Paper: A 12-Year Old Summary of Robust Unstructured Simplicity - Bitcoin News",
#    'description': "<ol><li>Satoshi Nakamoto's Bitcoin White Paper: A 12-Year Old Summary of Robust Unstructured Simplicity\xa0\xa0Bitcoin News\r\n</li><li>MicroStrategy's bottom line gets beefier on Bitcoin moves: Bad crypto news of the week\xa0\xa0Cointelegraph\r\n</li><li>The Crypto Daily – …",
#    'url': 'https://news.bitcoin.com/satoshi-nakamotos-bitcoin-white-paper-a-12-year-old-summary-of-robust-unstructured-simplicity/',
#    'urlToImage': 'https://news.bitcoin.com/wp-content/uploads/2020/10/satoshi-nakamotos-bitcoin-white-paper-a-12-year-old-summary-of-robust-unstructured-simplicity.jpg',
#    'publishedAt': '2020-11-01T00:32:52Z',
#    'content': 'Cryptocurrency supporters all around the world are celebrating the fact that today is the 12th anniversary of the Bitcoin white paper, a summary of the invention created by the pseudonymous inventor … [+4917 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': 'Every Major Bank Will Have Exposure to Bitcoin, Says Renowned Fund Manager Bill Miller | News - Bitcoin News',
#    'description': "<ol><li>Every Major Bank Will Have Exposure to Bitcoin, Says Renowned Fund Manager Bill Miller | News\xa0\xa0Bitcoin News\r\n</li><li>Bitcoin at $15K is now bigger than PayPal, Coca-Cola, Netflix, Disney\xa0\xa0Cointelegraph\r\n</li><li>Fear is in the air, but here's why inv…",
#    'url': 'https://news.bitcoin.com/bill-miller-every-major-bank-exposure-bitcoin/',
#    'urlToImage': 'https://news.bitcoin.com/wp-content/uploads/2019/09/bill-miller-bitcoin.jpg',
#    'publishedAt': '2020-11-08T23:23:28Z',
#    'content': "Iran's New Crypto Law Requires Miners to Sell Bitcoin Directly to Central Bank to Fund Imports\r\nIran has reportedly revised the country's cryptocurrency regulation to require licensed bitcoin miners … [+8054 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Dale Smith',
#    'title': 'PayPal adds cryptocurrency buying, selling and shopping to its platform - CNET',
#    'description': 'PayPal users will soon be able to trade bitcoin and other digital currency directly from the PayPal app.',
#    'url': 'https://www.cnet.com/personal-finance/paypal-adds-cryptocurrency-buying-selling-and-shopping-to-its-platform/',
#    'urlToImage': 'https://cnet4.cbsistatic.com/img/NNtYar_4nQqxYfnS_J40T2SGR4g=/1200x630/2020/09/01/05cbbec2-db5c-4db5-89e1-4f67c6b14292/paypal-logo-phone-6854.jpg',
#    'publishedAt': '2020-10-21T14:29:34Z',
#    'content': "PayPal will soon allow it's 305 million active users to buy, hold and sell cryptocurrencies like Bitcoin.\r\nAngela Lang/CNET\r\nPayPal users looking for an alternative way to stash their cash will soon … [+983 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin extends gains after PayPal move to accept cryptocurrencies - Reuters',
#    'description': 'Bitcoin extended its gains on Wednesday after PayPal Holdings Inc said it will allow customers to buy, sell and hold cryptocurrencies.',
#    'url': 'https://www.reuters.com/article/us-cryptoc-currencies-idUSKBN2761PV',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538308040&r=LYNXMPEG9K13G&w=800',
#    'publishedAt': '2020-10-21T12:26:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic\r\nLONDON (Reuters) - Bitcoin extended its… [+180 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin extends gains after PayPal move to accept cryptocurrencies - Reuters India',
#    'description': 'Bitcoin extended its gains on Wednesday after PayPal Holdings Inc said it will allow customers to buy, sell and hold cryptocurrencies.',
#    'url': 'https://in.reuters.com/article/cryptoc-currencies-idINKBN2761P7',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538306885&r=LYNXMPEG9K135&w=800',
#    'publishedAt': '2020-10-21T12:20:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic/File Photo\r\nLONDON (Reuters) - Bitcoin e… [+191 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Pete Schroeder',
#    'title': "U.S. seizes over $1 billion in bitcoin tied to 'Silk Road' - Reuters",
#    'description': 'The U.S. Justice Department announced Thursday it had seized over $1 billion worth of bitcoin associated with the underground online marketplace Silk Road.',
#    'url': 'https://www.reuters.com/article/us-usa-justice-crypto-currency-idUSKBN27L2I9',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201105&t=2&i=1540150143&r=LYNXMPEGA41I3&w=800',
#    'publishedAt': '2020-11-05T17:45:00Z',
#    'content': 'FILE PHOTO: A Bitcoin (virtual currency) paper wallet with QR codes and a coin are seen in an illustration picture taken at La Maison du Bitcoin in Paris, France, May 27, 2015. REUTERS/Benoit Tessier… [+990 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin extends gains after PayPal move to accept cryptocurrencies - Reuters UK',
#    'description': 'Bitcoin extended its gains on Wednesday after PayPal Holdings Inc said it will allow customers to buy, sell and hold cryptocurrencies.',
#    'url': 'https://uk.reuters.com/article/us-cryptoc-currencies-idUKKBN2761PV',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538308040&r=LYNXMPEG9K13G&w=800',
#    'publishedAt': '2020-10-21T12:29:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic\r\nLONDON (Reuters) - Bitcoin extended its… [+180 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'Bitcoin hits highest level since Jan. 2018 amid post-election volatility - Reuters',
#    'description': "Bitcoin's <BTC=BTSP> price rose to more than $14,900 on Thursday, its highest level since January 2018, amid volatility caused by the U.S. election and investor hopes that more central bank stimulus to support economies hit by the COVID-19 pandemic will push …",
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-bitcoin-idUSKBN27L234',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201105&t=2&i=1540130858&r=LYNXMPEGA4185&w=800',
#    'publishedAt': '2020-11-05T15:23:00Z',
#    'content': "LONDON (Reuters) - Bitcoin's BTC=BTSP price rose to more than $14,900 on Thursday, its highest level since January 2018, amid volatility caused by the U.S. election and investor hopes that more centr… [+2480 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'Bitcoin hits highest level since January 2018 amid post-election volatility - Reuters UK',
#    'description': "Bitcoin's price rose to more than $14,900 on Thursday, its highest level since January 2018, amid volatility caused by the U.S. election and investor hopes that more central bank stimulus to support economies hit by the COVID-19 pandemic will push up the valu…",
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-bitcoin-idUKKBN27L234',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201105&t=2&i=1540130858&r=LYNXMPEGA4185&w=800',
#    'publishedAt': '2020-11-05T15:22:00Z',
#    'content': 'LONDON (Reuters) - Bitcoins price rose to more than $14,900 on Thursday, its highest level since January 2018, amid volatility caused by the U.S. election and investor hopes that more central bank st… [+2469 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': "BoE's Bailey sees little intrinsic value in Bitcoin - Reuters",
#    'description': 'Bank of England Governor Andrew Bailey said on Monday it was hard to see how Bitcoin <BTC=> had any intrinsic value and he cautioned over its use as a means of payment.',
#    'url': 'https://www.reuters.com/article/us-britain-boe-bailey-bitcoin-idUSKBN26X2AH',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201012&t=2&i=1537165099&r=LYNXMPEG9B1DJ&w=800',
#    'publishedAt': '2020-10-12T17:08:00Z',
#    'content': 'By Reuters Staff\r\nLONDON (Reuters) - Bank of England Governor Andrew Bailey said on Monday it was hard to see how Bitcoin BTC= had any intrinsic value and he cautioned over its use as a means of paym… [+420 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Quibi is shutting down',
#    'description': 'The end is in sight for Quibi, PayPal adds cryptocurrency support and Netflix tests a new promotional strategy. This is your Daily Crunch for October 21, 2020. The big story: Quibi is shutting down The much-hyped streaming video app led by Jeffrey Katzenberg …',
#    'url': 'http://techcrunch.com/2020/10/21/daily-crunch-quibi-is-be-shutting-down/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/04/Coming-to-Quibi-..jpg?w=711',
#    'publishedAt': '2020-10-21T22:11:04Z',
#    'content': 'The end is in sight for Quibi, PayPal adds cryptocurrency support and Netflix tests a new promotional strategy. This is your Daily Crunch for October 21, 2020.\r\nThe big story: Quibi is shutting down\r… [+3035 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': "BoE's Bailey sees little intrinsic value in Bitcoin - Reuters UK",
#    'description': 'Bank of England Governor Andrew Bailey said on Monday it was hard to see how Bitcoin <BTC=> had any intrinsic value and he cautioned over its use as a means of payment.',
#    'url': 'https://uk.reuters.com/article/us-britain-boe-bailey-bitcoin-idUKKBN26X2AH',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201012&t=2&i=1537165099&r=LYNXMPEG9B1DJ&w=800',
#    'publishedAt': '2020-10-12T17:12:00Z',
#    'content': 'By Reuters Staff\r\nLONDON (Reuters) - Bank of England Governor Andrew Bailey said on Monday it was hard to see how Bitcoin BTC= had any intrinsic value and he cautioned over its use as a means of paym… [+420 chars]'},
#   {'source': {'id': None, 'name': 'Boing Boing'},
#    'author': 'Mark Frauenfelder',
#    'title': '$1 billion bitcoin mystery solved',
#    'description': "Earlier this week someone moved nearly a billion dollars worth of bitcoin (69,369 BTC\xa0) from a wallet address that hadn't been active since 2015. Speculation was rampant about who it could be. Kim Jong Un? An Eastern European crime syndicate? — Read the rest",
#    'url': 'https://boingboing.net/2020/11/05/1-billion-bitcoin-mystery-solved.html',
#    'urlToImage': 'https://i0.wp.com/boingboing.net/wp-content/uploads/2020/11/CleanShot-2020-11-05-at-08.38.48@2x-scaled.jpg?fit=1200%2C346&ssl=1',
#    'publishedAt': '2020-11-05T18:42:09Z',
#    'content': "Earlier this week someone moved nearly a billion dollars worth of bitcoin (69,369 BTC\xa0) from a wallet address that hadn't been active since 2015. Speculation was rampant about who it could be. Kim Jo… [+1213 chars]"},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': 'Lyft is adding Venmo as a payment option',
#    'description': 'In the coming weeks, Lyft riders in the US will be able to pay for their trips with Venmo. That should make it easier for you to split the cost of rides with your friends and family — at least when you feel safe enough to travel in groups again. You can use V…',
#    'url': 'https://www.engadget.com/lyft-venmo-payment-option-190605539.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-08%2Ff20353a0-dd83-11ea-a78f-e8e0895e87cc&client=amp-blogside-v2&signature=00a8eb59647e4ce26025903a4a531bb2b0b5233e',
#    'publishedAt': '2020-10-22T19:06:05Z',
#    'content': 'In the coming weeks, Lyft riders in the US will be able to pay for their trips with Venmo. That should make it easier for you to split the cost of rides with your friends and family — at least when y… [+381 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': "Verified 'Elon Musk' Twitter account celebrates election with crypto scam",
#    'description': 'The 2020 U.S. presidential election may still be unresolved as of Wednesday morning, but "Elon Musk" wanted to celebrate! And, like so many countless times before, he decided the best way to do so was to give away scores of cryptocurrency via his Twitter acco…',
#    'url': 'https://mashable.com/article/elon-musk-twitter-cryptocurrency-scam-donald-trump-replies/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F11%252F04%252Faf%252Ff4f50776948645a3984ab833e1abb256.89f77.jpg%252F1200x630.jpg?signature=BRXMreuW4GELTNJx580vwu2DHsw=',
#    'publishedAt': '2020-11-04T18:52:12Z',
#    'content': 'The 2020 U.S. presidential election may still be unresolved as of Wednesday morning, but "Elon Musk" wanted to celebrate! And, like so many countless times before, he decided the best way to do so wa… [+2453 chars]'},
#   {'source': {'id': None, 'name': 'Theguardian.comtechnology'},
#    'author': 'Alex Hern Technology editor',
#    'title': 'Charities in a bind after cybercriminals donate $10,000 in bitcoin',
#    'description': 'Children International and The Water Project have no way of refunding Darkside groupNo charity wants to turn down donations, particularly in the middle of a funding crunch. But what if donations come from a surprising source – hackers?While it may sound like …',
#    'url': 'https://amp.theguardian.comtechnology/2020/oct/20/charities-in-a-bind-after-cybercriminals-donate-10000-in-bitcoin',
#    'urlToImage': 'https://i.guim.co.uk/img/media/aa64e9f218b2a34e9b2ea25851dd9d936853df30/0_0_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=041dfc75356809de6cd0042e4d8ea44b',
#    'publishedAt': '2020-10-20T16:27:54Z',
#    'content': 'No charity wants to turn down donations, particularly in the middle of a funding crunch. But what if donations come from a surprising source hackers?\r\nWhile it may sound like a modern-day version of … [+4034 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters India',
#    'description': "PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://in.reuters.com/article/paypal-cryptocurrency-idINKBN2761MI',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538303222&r=LYNXMPEG9K11C&w=800',
#    'publishedAt': '2020-10-21T11:55:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments companys… [+2143 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters Canada',
#    'description': "PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://ca.reuters.com/article/ctech-us-paypal-cryptocurrency-idCAKBN2761L6-OCATC',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538301819&r=LYNXMPEG9K10U-OCATC&w=800',
#    'publishedAt': '2020-10-21T11:41:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments companys… [+2354 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters',
#    'description': "PayPal Holdings Inc <PYPL.O> joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://www.reuters.com/article/us-paypal-cryptocurrency-idUSKBN2761L6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538305193&r=LYNXMPEG9K10U&w=800',
#    'publishedAt': '2020-10-21T11:53:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc PYPL.O joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments c… [+2373 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera, Tom Wilson',
#    'title': "Analysis: Is PayPal's crypto move a game-changer for bitcoin? Probably not, say experts - Reuters",
#    'description': "PayPal Holdings Inc's <PYPL.O> decision to open its network to bitcoin and its rivals was hailed by virtual coin enthusiasts as a watershed moment for cryptocurrencies and their path towards becoming a widespread means of payment.",
#    'url': 'https://www.reuters.com/article/paypal-cryptocurrencies-analysis-int-idUSKBN2772J2',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201022&t=2&i=1538487410&r=LYNXMPEG9L1FI&w=800',
#    'publishedAt': '2020-10-22T16:30:00Z',
#    'content': "LONDON (Reuters) - PayPal Holdings Inc's PYPL.O decision to open its network to bitcoin and its rivals was hailed by virtual coin enthusiasts as a watershed moment for cryptocurrencies and their path… [+5207 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': 'Crypto hedge funds rack up steep gains on lending surge - Reuters Canada',
#    'description': 'Cryptocurrency hedge funds have posted hefty gains so far this year, benefiting from the surge in transactions that allow lenders and borrowers to transact without banks, as well as a steady rise in the bitcoin price.',
#    'url': 'https://ca.reuters.com/article/us-crypto-currencies-funds-idCAKBN27F0XW',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201030&t=2&i=1539383922&r=LYNXMPEG9T0KH&w=800',
#    'publishedAt': '2020-10-30T07:49:00Z',
#    'content': 'By Gertrude Chavez-Dreyfuss\r\nNEW YORK (Reuters) - Cryptocurrency hedge funds have posted hefty gains so far this year, benefiting from the surge in transactions that allow lenders and borrowers to tr… [+2049 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': 'Crypto hedge funds rack up steep gains on lending surge - Reuters',
#    'description': 'Cryptocurrency hedge funds have posted hefty gains so far this year, benefiting from the surge in transactions that allow lenders and borrowers to transact without banks, as well as a steady rise in the bitcoin price.',
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-funds-idUSKBN27F0XW',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201030&t=2&i=1539383922&r=LYNXMPEG9T0KH&w=800',
#    'publishedAt': '2020-10-30T07:50:00Z',
#    'content': 'NEW YORK (Reuters) - Cryptocurrency hedge funds have posted hefty gains so far this year, benefiting from the surge in transactions that allow lenders and borrowers to transact without banks, as well… [+2020 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters',
#    'description': "PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://www.reuters.com/article/paypal-cryptocurrency-idUSKBN2761MI',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538303222&r=LYNXMPEG9K11C&w=800',
#    'publishedAt': '2020-10-21T11:41:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments companys… [+2365 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera, Tom Wilson',
#    'title': "Is PayPal's crypto move a game-changer for bitcoin? Probably not, say experts - Reuters India",
#    'description': "PayPal Holdings Inc's decision to open its network to bitcoin and its rivals was hailed by virtual coin enthusiasts as a watershed moment for cryptocurrencies and their path towards becoming a widespread means of payment.",
#    'url': 'https://www.reuters.com/article/us-paypal-cryptocurrencies-analysis-idINKBN2772I4',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201022&t=2&i=1538486816&r=LYNXMPEG9L1F3&w=800',
#    'publishedAt': '2020-10-22T16:21:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Incs decision to open its network to bitcoin and its rivals was hailed by virtual coin enthusiasts as a watershed moment for cryptocurrencies and their path towards… [+5180 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Shalini Nagarajan',
#    'title': 'Billionaire investor Mike Novogratz won half a bitcoin in an election bet, then gave it away through a self-hosted lottery',
#    'description': 'Summary List Placement\n\n<ul>\n<li>Billionaire investor Mike Novogratz won half a Bitcoin in an election bet over the weekend, but then hosted a lottery to hand it out to "new Bitcoiners."\xa0</li>\n<li>Novogratz, the CEO and founder of crypto-focused merchant bank…',
#    'url': 'https://www.businessinsider.com/billionaire-investor-novogratz-won-half-bitcoin-election-bet-lottery-2020-11',
#    'urlToImage': 'https://images2.markets.businessinsider.com/5f36ec13e89ebf001f044d76?format=jpeg',
#    'publishedAt': '2020-11-09T10:51:51Z',
#    'content': 'REUTERS/Rick Wilking\r\nBillionaire investor Mike Novogratz said he won half a Bitcoin in an election bet on Saturday, and gave it up in a self-hosted lottery to a Twitter user.\r\nHalf a Bitcoin is curr… [+1851 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Andy Greenberg',
#    'title': 'Feds Seize $1 Billion in Stolen Silk Road Bitcoins',
#    'description': 'A hacker identified only as Individual X had been sitting on a cryptocurrency goldmine for seven years before the IRS came knocking.',
#    'url': 'https://www.wired.com/story/feds-seize-billion-stolen-silk-road-bitcoin/',
#    'urlToImage': 'https://media.wired.com/photos/5fa4446bba670daaf8e97a45/191:100/w_1280,c_limit/Sec_IRS_1133157848.jpg',
#    'publishedAt': '2020-11-05T20:01:37Z',
#    'content': 'More than seven years have passed since Ross Ulbricht was arrested in the science fiction section of a San Francisco library and charged with running the sprawling, dark web drug bazaar known as the … [+3794 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Dan Goodin',
#    'title': 'Feds seize $1 billion in bitcoin from Silk Road drug marketplace',
#    'description': 'Forfeiture comes two days after mystery party transferred 69,369 BTC out of wallet.',
#    'url': 'https://arstechnica.com/tech-policy/2020/11/feds-seize-1-billion-in-bitcoin-from-silk-road-drug-marketplace/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2015/01/bitcoin.blockchain-640x215.jpg',
#    'publishedAt': '2020-11-05T18:11:14Z',
#    'content': '14 with 14 posters participating\r\nOn Wednesday, Ars reported that someone had transferred close to $1 billion in bitcoin out of a wallet likely associated with the Silk Road crime bazaar. Now we know… [+1674 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Reed Alexander',
#    'title': "The world's largest digital currency asset manager took in $1 billion in new investment in the third quarter. Here's why investors are feeling so bullish about bitcoin and ethereum.",
#    'description': "Summary List Placement\n\nPortions of the global economy melted down in 2020, but an emerging asset class seems to have reinforced its staying power amid the chaos.\nGrayscale Investments, the world's largest digital-currency asset manager, notched its largest-e…",
#    'url': 'https://www.businessinsider.com/grayscale-investments-digital-asset-investment-report-bitcoin-crypto-2020-10',
#    'urlToImage': 'https://i.insider.com/5f861adf91aa9e001880b781?width=1200&format=jpeg',
#    'publishedAt': '2020-10-14T13:00:00Z',
#    'content': "Portions of the global economy melted down in 2020, but an emerging asset class seems to have reinforced its staying power amid the chaos.\r\nGrayscale Investments, the world's largest digital-currency… [+5397 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto hedge funds rack up steep gains on lending surge - Reuters',
#    'description': 'Crypto hedge funds rack up steep gains on lending surge\xa0\xa0Reuters',
#    'url': 'https://www.reuters.com/article/crypto-currencies-funds-idUSL1N2HI21O',
#    'urlToImage': None,
#    'publishedAt': '2020-10-30T05:00:00Z',
#    'content': 'Financials\r\nGertrude Chavez-Dreyfuss\r\nNEW YORK, Oct 30 (Reuters) - Cryptocurrency hedge funds have posted hefty gains so far this year, benefiting from the surge in transactions that allow lenders an… [+2244 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Alexis Akwagyiram',
#    'title': 'With Instagram, hashtags and bitcoin, young Nigerians boost anti-police protests - Reuters Canada',
#    'description': 'Ozioma Egemasi says Nigerian police slapped, whipped and struck him with the butt of a pistol when he refused to pay them a bribe. Then he heard them discuss whether to kill him.',
#    'url': 'https://ca.reuters.com/article/us-nigeria-protests-police-activists-idCAKBN27418O',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201019&t=2&i=1538013621&r=LYNXMPEG9I0SK&w=800',
#    'publishedAt': '2020-10-19T10:28:00Z',
#    'content': 'By Alexis Akwagyiram\r\nLAGOS (Reuters) - Ozioma Egemasi says Nigerian police slapped, whipped and struck him with the butt of a pistol when he refused to pay them a bribe. Then he heard them discuss w… [+5359 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Lomas',
#    'title': 'Twitter hack probe leads to call for cybersecurity rules for social media giants',
#    'description': 'An investigation into this summer’s Twitter hack by the New York State Department of Financial Services (NYSDFS) has ended with a stinging rebuke for how easily Twitter let itself be duped by a “simple” social engineering technique — and with a wider call for…',
#    'url': 'http://techcrunch.com/2020/10/14/twitter-hack-probe-leads-to-call-for-cybersecurity-rules-for-social-media-giants/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/08/twitter-app-icon-ios.jpg?w=695',
#    'publishedAt': '2020-10-14T14:32:18Z',
#    'content': 'An investigation into this summer’s Twitter hack by the New York State Department of Financial Services (NYSDFS) has ended with a stinging rebuke for how easily Twitter let itself be duped by a “simp… [+4268 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Yaron Yitzhak',
#    'title': 'Is Bitcoin a good hedge against the market? It depends on your horizon',
#    'description': 'Is it a currency? Is it an asset? Or is it perhaps… a commodity? In an effort to drive up its price, (in)famous crypto evangelicals have been coming up and attributing an increasing number of use cases to Bitcoin. One of the most profound ones, often touted b…',
#    'url': 'https://thenextweb.com/hardfork/2020/11/06/is-bitcoin-a-good-hedge-against-the-market-it-depends-on-your-horizon/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2020%2F11%2Fpexels-worldspectrum-844127.jpg&signature=10153f9bc83756cc97bfd55c4ea2688a',
#    'publishedAt': '2020-11-06T11:00:27Z',
#    'content': 'Is it a currency? Is it an asset? Or is it perhaps a commodity? In an effort to drive up its price, (in)famous crypto evangelicals have been coming up and attributing an increasing number of use case… [+2994 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'David Canellis',
#    'title': 'NY watchdog attacks Twitter over ‘jarringly easy’ Bitcoin scam hack',
#    'description': 'The New York Department of Financial Services (DFS) has called on the government to regulate\xa0social media giants in response to July’s dramatic Bitcoin-themed Twitter hack. “Given that Twitter is a publicly traded, $37 billion technology company, it was surpr…',
#    'url': 'https://thenextweb.com/hardfork/2020/10/14/ny-watchdog-attacks-twitter-over-jarringly-easy-bitcoin-scam-hack/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F02%2Ftwitter-dorsey-bitcoin-blockchain-cryptocurrency.jpg&signature=4fd7da170506f89bdae8c93ff90c3719',
#    'publishedAt': '2020-10-14T15:44:12Z',
#    'content': 'The New York Department of Financial Services (DFS) has called on the government to regulate\xa0social media giants in response to Julys dramatic Bitcoin-themed Twitter hack.\r\nGiven that Twitter is a pu… [+2594 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Ben Winck',
#    'title': 'One technical indicator signals bitcoin can lose steam after 10% PayPal rally',
#    'description': "Summary List Placement\n\n<ul>\n<li>Bitcoin's massive leap since Wednesday may have gone too far, too fast.</li>\n<li>The world's most popular cryptocurrency surged above $13,000 on Wednesday and continued to climb through the week after PayPal announced its user…",
#    'url': 'https://www.businessinsider.com/bitcoin-price-rally-paypal-outlook-overbought-rsi-cryptocurrency-technicals-btc-2020-10',
#    'urlToImage': 'https://i.insider.com/5f92c6b9abcd0c0018d69489?format=jpeg',
#    'publishedAt': '2020-10-23T13:04:20Z',
#    'content': "A chain of block erupters used for Bitcoin mining is pictured at the Plug and Play Tech Center in Sunnyvale, California, October 28, 2013.\r\nREUTERS/Stephen Lam\r\n<ul><li>Bitcoin's massive leap since W… [+2829 chars]"},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jae Thomas',
#    'title': 'Learn the ins and outs of trading with this training bundle on sale',
#    'description': 'TL;DR: Learn how to trade and understand the stock market with the Complete Wall Street and Cryptocurrency Trading Bootcamp, on sale for $30 as of Oct. 22.\xa0\n\nGetting into cryptocurrency and trading might seem daunting, but these paths can actually be quite ac…',
#    'url': 'https://mashable.com/shopping/oct-22-wall-street-cryptocurrency-trading-bundle/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F10%252F22%252Faf%252F651b4228d7fc4c36812772280a197afb.44cf8.jpg%252F1200x630.jpg?signature=B_2Dc4fS1WLFTkq0mbkyai0SKPU=',
#    'publishedAt': '2020-10-22T09:00:00Z',
#    'content': 'TL;DR: Learn how to trade and understand the stock marketwith theComplete Wall Street and Cryptocurrency Trading Bootcamp, on sale for $30 as of Oct. 22.\xa0\r\nGetting into cryptocurrency and trading mig… [+1566 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Hong Kong will require all cryptocurrency trading platforms to be regulated - SFC - Reuters UK',
#    'description': "Hong Kong will require all cryptocurrency trading platforms to be regulated whether or not they trade securities, the city's securities watchdog said on Tuesday.",
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-hongkong-regulator-idUKKBN27J07N',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201103&t=2&i=1539742507&r=LYNXMPEGA203S&w=800',
#    'publishedAt': '2020-11-03T02:38:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic\r\nHONG KONG (Reuters) - Hong Kong will re… [+424 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'John Biggs',
#    'title': 'Scammers Are Pretending They Saw You Naked on Zoom',
#    'description': 'In an era of Jeffrey Toobin and always-on webcams, scammers have launched a new grift that involves claiming that they have access to your naked Zoom videos. Trust me: They don’t. But that doesn’t mean they won’t try to convince you otherwise.',
#    'url': 'https://gizmodo.com/scammers-are-pretending-they-saw-you-naked-on-zoom-1845528854',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ag11enfnxodjmqhufnfz.jpg',
#    'publishedAt': '2020-10-30T16:20:00Z',
#    'content': 'In an era of Jeffrey Toobin and always-on webcams, scammers have launched a new grift that involves claiming that they have access to your naked Zoom videos. \r\nTrust me: They dont. But that doesnt me… [+2043 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': "Crypto crime slows in 2020, but 'DeFi' hacks rise: CipherTrace report - Reuters",
#    'description': 'Losses from cryptocurrency thefts, hacks, and fraud declined to $1.8 billion for the first 10 months of the year compared with last year, but crime in the hot "decentralized finance" sector rose, according to a report from crypto intelligence company CipherTr…',
#    'url': 'https://www.reuters.com/article/crypto-currencies-crime-int-idUSKBN27Q29W',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201110&t=2&i=1540713735&r=LYNXMPEGA919E&w=800',
#    'publishedAt': '2020-11-10T15:08:00Z',
#    'content': 'NEW YORK (Reuters) - Losses from cryptocurrency thefts, hacks, and fraud declined to $1.8 billion for the first 10 months of the year compared with last year, but crime in the hot decentralized finan… [+2089 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': "Crypto crime slows in 2020, but 'DeFi' hacks rise: CipherTrace report - Reuters India",
#    'description': 'Losses from cryptocurrency thefts, hacks, and fraud declined to $1.8 billion for the first 10 months of the year compared with last year, but crime in the hot "decentralized finance" sector rose, according to a report from crypto intelligence company CipherTr…',
#    'url': 'https://www.reuters.com/article/crypto-currencies-crime-idINKBN27Q238',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201110&t=2&i=1540706669&r=LYNXMPEGA9168&w=800',
#    'publishedAt': '2020-11-10T14:21:00Z',
#    'content': 'NEW YORK (Reuters) - Losses from cryptocurrency thefts, hacks, and fraud declined to $1.8 billion for the first 10 months of the year compared with last year, but crime in the hot decentralized finan… [+2100 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Crypto crime slows in 2020, but 'DeFi' hacks rise: CipherTrace report - Reuters India",
#    'description': "Crypto crime slows in 2020, but 'DeFi' hacks rise: CipherTrace report\xa0\xa0Reuters India",
#    'url': 'https://in.reuters.com/article/crypto-currencies-crime-idINKBN27Q238',
#    'urlToImage': None,
#    'publishedAt': '2020-11-10T14:21:00Z',
#    'content': 'FILE PHOTO: The exchange rates and logos of Bitcoin (BTH), Ether (ETH), Litecoin (LTC) and Bitcoin Cash (BCH) are seen on the display of a cryptocurrency ATM of blockchain payment service provider Va… [+2312 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Microsoft Engineer Gets Nine Years For Stealing $10 Million From Microsoft',
#    'description': "A former Microsoft software engineer from Ukraine has been sentenced to nine years in prison for stealing more than $10 million in store credit from Microsoft's online store. Ars Technica reports: From 2016 to 2018, Volodymyr Kvashuk worked for Microsoft as a…",
# ...
#    'author': 'Lorenzo Franceschi-Bicchierai, Jordan Pearson',
#    'title': 'U.S. Feds Seized Nearly $1 Billion in Bitcoin from Wallet Linked to Silk Road',
#    'description': 'Speculation kicked off after someone moved the huge sum on Tuesday, and now we know who it was: the U.S. government.',
#    'url': 'https://www.vice.com/en/article/akdgz8/us-feds-seize-1-billion-in-bitcoin-from-wallet-linked-to-silk-road',
#    'urlToImage': 'https://video-images.vice.com//articles/5fa43e12c56809009d4e6a69/lede/1604599876716-bitcoin.jpeg?image-resize-opts=Y3JvcD0xeHc6MC44NDN4aDsweHcsMC4wNDl4aCZyZXNpemU9MTIwMDoqJnJlc2l6ZT0xMjAwOio',
#    'publishedAt': '2020-11-05T18:15:04Z',
#    'content': 'On Tuesday, someone emptied out one of the most mysterious and most valuable Bitcoin wallets in existence, which contained almost $1 billion dollars linked to the notorious Silk Road dark web market.… [+1975 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': "Crypto crime slows in 2020, but 'DeFi' hacks rise - CipherTrace report - Reuters Canada",
#    'description': 'Losses from cryptocurrency thefts, hacks, and fraud declined to $1.8 billion for the first 10 months of the year compared with last year, but crime in the hot "decentralized finance" sector rose, according to a report from crypto intelligence company CipherTr…',
#    'url': 'https://ca.reuters.com/article/us-crypto-currencies-crime-idCAKBN27Q29N',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201110&t=2&i=1540713461&r=LYNXMPEGA919A&w=800',
#    'publishedAt': '2020-11-10T15:09:00Z',
#    'content': 'By Gertrude Chavez-Dreyfuss\r\nNEW YORK (Reuters) - Losses from cryptocurrency thefts, hacks, and fraud declined to $1.8 billion for the first 10 months of the year compared with last year, but crime i… [+1945 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Jonathan Stempel',
#    'title': "Twitter's security fell short before hack targeting celebrities, regulator says - Reuters Canada",
#    'description': 'Twitter Inc suffered from cybersecurity shortfalls that enabled a "simple" hack attributed to a Florida teenager to take over the accounts of several of the world\'s most famous people in July, according to a report released on Wednesday.',
#    'url': 'https://ca.reuters.com/article/ctech-us-twitter-cyber-idCAKBN26Z1ZM-OCATC',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201014&t=2&i=1537435759&r=LYNXMPEG9D153-OCATC&w=800',
#    'publishedAt': '2020-10-14T13:36:00Z',
#    'content': 'By Jonathan Stempel\r\nNEW YORK (Reuters) - Twitter Inc suffered from cybersecurity shortfalls that enabled a simple hack attributed to a Florida teenager to take over the accounts of several of the wo… [+2105 chars]'},
#   {'source': {'id': None, 'name': 'Medium'},
#    'author': 'David Golumbia',
#    'title': 'Cryptocurrency Is Garbage. So Is Blockchain',
#    'description': 'Note: Amy Castor and David Gerard provided extensive commentary, editorial help, and in some cases the actual words used in this piece. I have been writing about cryptocurrencies since at least 2013…',
#    'url': 'https://davidgolumbia.medium.com/cryptocurrency-is-garbage-so-is-blockchain-3e80078e77fe',
#    'urlToImage': 'https://miro.medium.com/max/650/0*L9jW54HNGZNu3Tkd.jpg',
#    'publishedAt': '2020-11-09T18:42:44Z',
#    'content': 'Overwhelming evidence shows that the blockchain/cryptocurrency space is mostly fraudulent\r\nsource: https://www.helpnetsecurity.com/2018/02/05/look-inside-cryptocurrency-fraud/\r\nNote: Amy Castor and D… [+39759 chars]'},
#   {'source': {'id': None, 'name': 'Boing Boing'},
#    'author': 'Xeni Jardin',
#    'title': 'Cybersecurity agency warns of \'imminent, increased cybercrime threat to U.S. hospitals and healthcare providers"',
#    'description': 'On Wednesday night less than one week before the election, as COVID-19 cases spike throughout the United States, the nation\'s cybersecurity agency says: "there is an imminent and increased cybercrime threat to U.S. hospitals and healthcare providers."\n\n\n\nHere…',
#    'url': 'https://boingboing.net/2020/10/28/cybersecurity-agency-warns-of-imminent-increased-cybercrime-threat-to-u-s-hospitals-and-healthcare-providers.html',
#    'urlToImage': 'https://i2.wp.com/boingboing.net/wp-content/uploads/2019/10/Hackers.jpg?fit=1200%2C799&ssl=1',
#    'publishedAt': '2020-10-29T03:37:31Z',
#    'content': 'On Wednesday night less than one week before the election, as COVID-19 cases spike throughout the United States, the nation\'s cybersecurity agency says: "there is an imminent and increased cybercrime… [+1918 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Katie Canales',
#    'title': "Twitter's Q3 earnings just blew past Wall Street's expectations with $936 million in revenue, but user growth majorly slumped (TWTR)",
#    'description': "Summary List Placement\n\nTwitter's stock is down 11% in after-hours trading, as the company blew past analyst expectations on revenue but fell short of user growth for Q3.\nHere are the key figures from its third-quarter financials, with expectations compiled b…",
#    'url': 'https://www.businessinsider.com/twitter-q3-2020-earnings-jack-dorsey-2020-10',
#    'urlToImage': 'https://i.insider.com/5f9b29bf69331a0011bc62eb?width=1200&format=jpeg',
#    'publishedAt': '2020-10-29T21:19:41Z',
#    'content': "Twitter's stock is down 11% in after-hours trading, as the company blew past analyst expectations on revenue but fell short of user growth for Q3.\r\nHere are the key figures from its third-quarter fin… [+1932 chars]"},
#   {'source': {'id': None, 'name': 'Hackaday'},
#    'author': 'Jenny List',
#    'title': 'Help, I’m Buried Alive By Tablets!',
#    'description': 'It’s fair to say that many Hackaday readers will have a propensity for hoarding electronic or tech junk. Who hasn’t hung on to something because “It might be useful someday”? Spare a thought for [Mike Drew], who in his own words is “buried alive by tablets”. …',
#    'url': 'https://hackaday.com/2020/11/10/help-im-buried-alive-by-tablets/',
#    'urlToImage': 'https://hackaday.com/wp-content/uploads/2020/11/intel-tablets-featured.jpg',
#    'publishedAt': '2020-11-10T21:00:00Z',
#    'content': 'It’s fair to say that many Hackaday readers will have a propensity for hoarding electronic or tech junk. Who hasn’t hung on to something because “It might be useful someday”? Spare a thought for [Mik… [+1428 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Emily Bary',
#    'title': ': PayPal will let customers buy cryptocurrencies and use them for online payments',
#    'description': 'PayPal Holdings Inc. plans to allow customers to buy cryptocurrency through their accounts and use cryptocurrency for merchant payments.',
#    'url': 'https://www.marketwatch.com/story/paypal-will-let-customers-buy-cryptocurrencies-and-use-them-for-online-payments-11603283352',
#    'urlToImage': 'https://images.mktw.net/im-247725/social',
#    'publishedAt': '2020-10-21T12:29:00Z',
#    'content': 'PayPal Holdings Inc. plans to allow customers to buy cryptocurrency through their accounts and use cryptocurrency for merchant payments. The company announced Wednesday that it is introducing a way f… [+2050 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera, Niket  Nishant, Eva  Mathews',
#    'title': 'PayPal tops estimates amid surge in online shopping but outlook disappoints - Reuters India',
#    'description': 'PayPal Holdings Inc <PYPL.O> beat Wall Street estimates for quarterly revenue and profit on Monday, boosted by a surge in digital payments as COVID-19 lockdowns worldwide drove more businesses online, but it forecast current-quarter profit below expectations.',
#    'url': 'https://in.reuters.com/article/paypal-results-idINKBN27J06M',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201103&t=2&i=1539741440&r=LYNXMPEGA2039&w=800',
#    'publishedAt': '2020-11-03T02:19:00Z',
#    'content': '(Reuters) - PayPal Holdings Inc PYPL.O beat Wall Street estimates for quarterly revenue and profit on Monday, boosted by a surge in digital payments as COVID-19 lockdowns worldwide drove more busines… [+2645 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss, Sujata Rao',
#    'title': 'Analysis: Clouds gather over battered dollar in U.S. election aftermath - Reuters UK',
#    'description': 'An increasingly bearish picture is unfolding for the U.S. dollar, which has suffered its worst week since March on signs that Federal Reserve money printing rather than government spending may be deployed to bolster the U.S. economy in the aftermath of electi…',
#    'url': 'https://uk.reuters.com/article/uk-usa-markets-dollar-analysis-idUKKBN27M2YZ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201106&t=2&i=1540320207&r=LYNXMPEGA51VA&w=800',
#    'publishedAt': '2020-11-07T00:00:00Z',
#    'content': '(Reuters) - An increasingly bearish picture is unfolding for the U.S. dollar, which has suffered its worst week since March on signs that Federal Reserve money printing rather than government spendin… [+3724 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Instant View: Biden wins presidential race, several networks say - Reuters India',
#    'description': 'Democrat Joe Biden captured the U.S. presidency on Saturday, several major television networks said. The news is likely to be welcomed by markets, as it could bring some certainty although President Donald Trump has not conceded, investors said.',
#    'url': 'https://www.reuters.com/article/us-usa-election-markets-instantview-idINKBN27N0MQ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201107&t=2&i=1540365964&r=LYNXMPEGA60GG&w=800',
#    'publishedAt': '2020-11-07T17:16:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Democrat Joe Biden captured the U.S. presidency on Saturday, several major television networks said. The news is likely to be welcomed by markets, as it could bring some… [+2832 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'INSTANT VIEW -Biden wins presidential race, several networks say - Reuters',
#    'description': 'Democrat Joe Biden captured the U.S. presidency on Saturday, several major television networks said. The news is likely to be welcomed by markets, as it could bring some certainty although President Donald Trump has not conceded, investors said.',
#    'url': 'https://www.reuters.com/article/usa-election-markets-idUSL1N2HT0FZ',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2020-11-07T17:12:00Z',
#    'content': 'By Reuters Staff\r\nNov 7 (Reuters) - Democrat Joe Biden captured the U.S. presidency on Saturday, several major television networks said. The news is likely to be welcomed by markets, as it could brin… [+2616 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'DOJ says it is suing for the forfeiture of $1B+ in bitcoin, seized on Tuesday, related to the Silk Road marketplace (Olga Kharif/Bloomberg)',
#    'description': 'Olga Kharif / Bloomberg:\nDOJ says it is suing for the forfeiture of $1B+ in bitcoin, seized on Tuesday, related to the Silk Road marketplace\xa0 —\xa0 - Justice Department seeks forfeiture of funds it seized Tuesday\xa0 — The news likely helped fuel 7% rise in Bitcoin…',
#    'url': 'https://www.techmeme.com/201105/p19',
#    'urlToImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iPcJG9LG3.XM/v1/1200x748.jpg',
#    'publishedAt': '2020-11-05T17:15:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'title': 'Bitcoin Soars Past $15,000 USD During U.S. Elections',
#    'description': 'Bitcoin (BTC) has just passed the $15,500 USD mark, gaining close to 8 percent in the last 24 hours. This new price now puts the cryptocurrency closer to its 2018 price when cryptocurrency was in a frenzy. On top of the surge from November 3, Bitcoin has expe…',
#    'url': 'https://hypebeast.com/2020/11/bitcoin-ethereum-new-high-growth-news',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2020%2F11%2Fbitcoin-ethereum-new-high-growth-news-tw.jpg?w=960&cbr=1&q=90&fit=max',
#    'publishedAt': '2020-11-06T17:28:38Z',
#    'content': 'Bitcoin (BTC) has just passed the $15,500 USD mark, gaining close to 8 percent in the last 24 hours. This new price now puts the cryptocurrency closer to its 2018 price when cryptocurrency was in a f… [+1063 chars]'},
#   {'source': {'id': None, 'name': 'Theguardian.comworld'},
#    'author': 'AFP in Helsinki',
#    'title': "'Shocking' hack of psychotherapy records in Finland affects thousands",
#    'description': 'Distressed patients flood support services after hack of private firm VastaamoThe confidential treatment records of tens of thousands of psychotherapy patients in Finland have been hacked and some leaked online, in what the interior minister described as “a s…',
#    'url': 'https://amp.theguardian.comworld/2020/oct/26/tens-of-thousands-psychotherapy-records-hacked-in-finland',
#    'urlToImage': 'https://i.guim.co.uk/img/media/4e461b653d9f4b9519c9f11285706142c5f21566/0_153_4252_2551/master/4252.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=8c9080b875857c7249a790602d339536',
#    'publishedAt': '2020-10-26T16:18:20Z',
#    'content': 'The confidential treatment records of tens of thousands of psychotherapy patients in Finland have been hacked and some leaked online, in what the interior minister described as a shocking act.\r\nDistr… [+3416 chars]'},
#   {'source': {'id': None, 'name': 'Theguardian.comworld'},
#    'author': 'Jason Burke Africa correspondent',
#    'title': 'Police brutality is just tip of the iceberg for protesters in Nigeria',
#    'description': 'Police violence prompted latest protests but anger at the government is growingThe signs held up by protesters have been clear. “We have no leaders,” said one. “The power of the youth is stronger than you that is in power,” ran another. A third read: “Nigeria…',
#    'url': 'https://amp.theguardian.comworld/2020/oct/21/police-brutality-just-tip-of-iceberg-protests-nigeria',
#    'urlToImage': 'https://i.guim.co.uk/img/media/2744f980292053450ca8434d8cab1e790f56bf5e/0_0_2784_1670/master/2784.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=0f22b5e30536fda8cc526f1b21f516ab',
#    'publishedAt': '2020-10-21T16:00:59Z',
#    'content': 'The signs held up by protesters have been clear. We have no leaders, said one. The power of the youth is stronger than you that is in power, ran another. A third read: Nigeria bleeds. \r\nThis last sta… [+3798 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Emily Bary',
#    'title': 'Earnings Results: Square stock rockets after earnings beat',
#    'description': 'Square Inc. shares gained in after-hours trading after the company reported better-than-expected earnings for the third quarter and noted that in-person payment volume for October was up relative to a year earlier.',
#    'url': 'https://www.marketwatch.com/story/square-stock-rockets-after-earnings-beat-11604612690',
#    'urlToImage': 'https://images.mktw.net/im-232119/social',
#    'publishedAt': '2020-11-05T21:44:00Z',
#    'content': 'Square Inc. shares gained in after-hours trading after the company reported better-than-expected earnings for the third quarter and noted that in-person payment volume for October was up relative to … [+1608 chars]'}]}

# %%
print(f"Total articles about Bitcoin: {bitcoin_headlines['totalResults']}")

# Show sample article
bitcoin_headlines["articles"][0]
# Out:
# Total articles about Bitcoin: 3939
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Romain Dillet',
#  'title': 'PayPal to let you buy and sell cryptocurrencies in the US',
#  'description': 'PayPal has partnered with cryptocurrency company Paxos to launch a new service. PayPal users in the U.S. will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon. PayPal plans to support Bitcoin, Ethereum, Bitcoin Cash and Lite…',
#  'url': 'http://techcrunch.com/2020/10/21/paypal-to-let-you-buy-and-sell-cryptocurrencies-in-the-us/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/07/GettyImages-887657568.jpg?w=600',
#  'publishedAt': '2020-10-21T13:28:15Z',
#  'content': 'PayPal has partnered with cryptocurrency company Paxos to launch a new service. PayPal users in the U.S. will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon.\r\nPay… [+2069 chars]'}

# %% [markdown]
# ## Fetch the Ethereum news articles

# %%
Eth_headlines = newsapi.get_top_headlines(q="Ethereum", language="en", country="us")
Eth_headlines
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %% [markdown]
# **News API with function "get_top_headlines" with country as US did not return any results for Ethereum, hence used "get_everything" function and discarded "country" to get details about Ethereum**

# %%
Ethereum_headlines=newsapi.get_everything(q="ethereum",
                                         language="en",
                                         page_size=100,
                                         sort_by="relevancy")
Ethereum_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 1154,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'PayPal to let you buy and sell cryptocurrencies in the US',
#    'description': 'PayPal has partnered with cryptocurrency company Paxos to launch a new service. PayPal users in the U.S. will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon. PayPal plans to support Bitcoin, Ethereum, Bitcoin Cash and Lite…',
#    'url': 'http://techcrunch.com/2020/10/21/paypal-to-let-you-buy-and-sell-cryptocurrencies-in-the-us/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/07/GettyImages-887657568.jpg?w=600',
#    'publishedAt': '2020-10-21T13:28:15Z',
#    'content': 'PayPal has partnered with cryptocurrency company Paxos to launch a new service. PayPal users in the U.S. will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon.\r\nPay… [+2069 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'Luxury watch maker Breitling issues digital certificates on the Ethereum blockchain',
#    'description': 'Breitling is partnering with Arianee to issue a new kind of certificates of authenticity for its luxury watches. Instead of relying on physical certificates, the watchmaker gives you a unique digital passport that certifies the origin of the watch. Behind the…',
#    'url': 'http://techcrunch.com/2020/10/15/luxury-watch-maker-breitling-issues-digital-certificates-on-the-ethereum-blockchain/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/10/Arianee.jpg?w=711',
#    'publishedAt': '2020-10-15T09:44:51Z',
#    'content': 'Breitling is partnering with Arianee to issue a new kind of certificates of authenticity for its luxury watches. Instead of relying on physical certificates, the watchmaker gives you a unique digital… [+1593 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Nick Statt',
#    'title': 'PayPal and Venmo will offer and accept cryptocurrency for all online payments',
#    'description': 'PayPal is joining the cryptocurrency industry with support for bitcoin and other digital currencies, making the digital payments company one of the most significant adopters of the technology to date. PayPal plans to extend support to its money-sending app Ve…',
#    'url': 'https://www.theverge.com/2020/10/21/21527288/paypal-cryptocurrency-support-buy-sell-venmo-bitcoin',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpbAVPi6j4xmC2Ug=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13546110/acastro_181126_1777_bitcoin_0001.jpg',
#    'publishedAt': '2020-10-21T19:49:27Z',
#    'content': 'PayPal is rolling out cryptocurrency support later this year\r\nIllustration by Alex Castro / The Verge\r\nPayPal on Wednesday announced it would begin supporting cryptocurrencies for the first time, all… [+2172 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Reed Alexander',
#    'title': "The world's largest digital currency asset manager took in $1 billion in new investment in the third quarter. Here's why investors are feeling so bullish about bitcoin and ethereum.",
#    'description': "Summary List Placement\n\nPortions of the global economy melted down in 2020, but an emerging asset class seems to have reinforced its staying power amid the chaos.\nGrayscale Investments, the world's largest digital-currency asset manager, notched its largest-e…",
#    'url': 'https://www.businessinsider.com/grayscale-investments-digital-asset-investment-report-bitcoin-crypto-2020-10',
#    'urlToImage': 'https://i.insider.com/5f861adf91aa9e001880b781?width=1200&format=jpeg',
#    'publishedAt': '2020-10-14T13:00:00Z',
#    'content': "Portions of the global economy melted down in 2020, but an emerging asset class seems to have reinforced its staying power amid the chaos.\r\nGrayscale Investments, the world's largest digital-currency… [+5397 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Australia's central bank launches digital currency project - Reuters UK",
#    'description': "Australia's central bank launches digital currency project\xa0\xa0Reuters UK",
#    'url': 'https://www.reuters.com/article/us-australia-rba-digitalcurrency-idUSKBN27H1VG',
#    'urlToImage': None,
#    'publishedAt': '2020-11-01T23:42:00Z',
#    'content': 'FILE PHOTO: A worker pushing a trolley walks with pedestrians past the Reserve Bank of Australia (RBA) head office in central Sydney, Australia, March 7, 2017. REUTERS/David Gray\r\nWorld News\r\nReuters… [+876 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': "Verified 'Elon Musk' Twitter account celebrates election with crypto scam",
#    'description': 'The 2020 U.S. presidential election may still be unresolved as of Wednesday morning, but "Elon Musk" wanted to celebrate! And, like so many countless times before, he decided the best way to do so was to give away scores of cryptocurrency via his Twitter acco…',
#    'url': 'https://mashable.com/article/elon-musk-twitter-cryptocurrency-scam-donald-trump-replies/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F11%252F04%252Faf%252Ff4f50776948645a3984ab833e1abb256.89f77.jpg%252F1200x630.jpg?signature=BRXMreuW4GELTNJx580vwu2DHsw=',
#    'publishedAt': '2020-11-04T18:52:12Z',
#    'content': 'The 2020 U.S. presidential election may still be unresolved as of Wednesday morning, but "Elon Musk" wanted to celebrate! And, like so many countless times before, he decided the best way to do so wa… [+2453 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Quibi is shutting down',
#    'description': 'The end is in sight for Quibi, PayPal adds cryptocurrency support and Netflix tests a new promotional strategy. This is your Daily Crunch for October 21, 2020. The big story: Quibi is shutting down The much-hyped streaming video app led by Jeffrey Katzenberg …',
#    'url': 'http://techcrunch.com/2020/10/21/daily-crunch-quibi-is-be-shutting-down/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/04/Coming-to-Quibi-..jpg?w=711',
#    'publishedAt': '2020-10-21T22:11:04Z',
#    'content': 'The end is in sight for Quibi, PayPal adds cryptocurrency support and Netflix tests a new promotional strategy. This is your Daily Crunch for October 21, 2020.\r\nThe big story: Quibi is shutting down\r… [+3035 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jennifer Spencer',
#    'title': '3 Lessons From the Summer DeFi Boom',
#    'description': 'Always do your own research.',
#    'url': 'https://www.entrepreneur.com/article/358661',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1604587733-GettyImages-1276486486.jpg',
#    'publishedAt': '2020-11-08T10:30:00Z',
#    'content': 'November\r\n8, 2020\r\n5 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nThe cryptocurrency world is prone to hype, whether on the grand scale of the ICO boom and Bitcoin price … [+5932 chars]'},
#   {'source': {'id': None, 'name': 'Boing Boing'},
#    'author': 'Rob Beschizza',
#    'title': 'PayPal to allow customers to buy and sell bitcoin and other cryptocurrencies',
#    'description': 'You will soon be able to buy and sell bitcoin, ethereum and other cryptocurrencies on PayPal. Reuters reports that the company is far from alone in offering this service to normies, but its "vast reach\' means it will be transformative. — Read the rest',
#    'url': 'https://boingboing.net/2020/10/21/paypal-to-allow-customers-to-buy-and-sell-bitcoin-and-other-cryptocurrencies.html',
#    'urlToImage': 'https://i0.wp.com/boingboing.net/wp-content/uploads/2019/07/bitcoin.jpg?fit=1024%2C576&ssl=1',
#    'publishedAt': '2020-10-21T13:15:36Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'Alex Smith',
#    'title': 'The Ledger Nano S crypto hardware wallet is down to $40 for Prime Day',
#    'description': "Amazon is treating Prime members to an onslaught of deals now that it's officially Prime Day. One discount could score you the Ledger Nano S crypto hardware wallet for just $39.99. That marks the best price this model has ever reached on Amazon and saves you …",
#    'url': 'https://www.androidcentral.com/ledger-nano-s-crypto-hardware-wallet-down-40-prime-day',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/ledger-nano-s-6he9-6he9.jpg',
#    'publishedAt': '2020-10-14T18:31:06Z',
#    'content': "Amazon is treating Prime members to an onslaught of deals now that it's officially Prime Day. One discount could score you the Ledger Nano S crypto hardware wallet for just $39.99. That marks the bes… [+1487 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters India',
#    'description': "PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://in.reuters.com/article/paypal-cryptocurrency-idINKBN2761MI',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538303222&r=LYNXMPEG9K11C&w=800',
#    'publishedAt': '2020-10-21T11:55:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments companys… [+2143 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters Canada',
#    'description': "PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://ca.reuters.com/article/ctech-us-paypal-cryptocurrency-idCAKBN2761L6-OCATC',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538301819&r=LYNXMPEG9K10U-OCATC&w=800',
#    'publishedAt': '2020-10-21T11:41:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments companys… [+2354 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters',
#    'description': "PayPal Holdings Inc <PYPL.O> joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://www.reuters.com/article/us-paypal-cryptocurrency-idUSKBN2761L6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538305193&r=LYNXMPEG9K10U&w=800',
#    'publishedAt': '2020-10-21T11:53:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc PYPL.O joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments c… [+2373 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': 'PayPal to allow cryptocurrency buying, selling and shopping on its network - Reuters',
#    'description': "PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments company's online wallets.",
#    'url': 'https://www.reuters.com/article/paypal-cryptocurrency-idUSKBN2761MI',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201021&t=2&i=1538303222&r=LYNXMPEG9K11C&w=800',
#    'publishedAt': '2020-10-21T11:41:00Z',
#    'content': 'LONDON (Reuters) - PayPal Holdings Inc joined the cryptocurrency market on Wednesday, allowing customers to buy, sell and hold bitcoin and other virtual coins using the U.S. digital payments companys… [+2365 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Ethereum Foundation says Ethereum 2.0 is set to launch on December 1 if enough validators are present on the network (Tim Copeland/Decrypt)',
#    'description': 'Tim Copeland / Decrypt:\nEthereum Foundation says Ethereum 2.0 is set to launch on December 1 if enough validators are present on the network\xa0 —\xa0 Version 1.0 of the Ethereum 2.0 specifications has been released and if all goes to plan, the blockchain upgrade s…',
#    'url': 'https://www.techmeme.com/201104/p14',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2020/09/ethereum-24b-tx-volume-august-gID_6.jpg',
#    'publishedAt': '2020-11-04T18:50:03Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Theregister.com'},
#    'author': 'Kieren McCarthy',
#    'title': 'Bitcoin value jumps as PayPal says it will accept cryptocurrencies... once it has the kinks worked out',
#    'description': 'Online payment goliath wants to encourage global use of virtual dosh\nThe value of Bitcoin spiked on Wednesday after PayPal said it would soon start accepting cryptocurrencies, including Bitcoin, Ethereum, Bitcoin Cash, and Litecoin, through its online payment…',
#    'url': 'https://www.theregister.com/2020/10/22/paypal_bitcoin_payment/',
#    'urlToImage': 'https://regmedia.co.uk/2019/10/21/shutterstock_bitcoin_atm.jpg',
#    'publishedAt': '2020-10-22T08:39:21Z',
#    'content': 'The value of Bitcoin spiked on Wednesday after PayPal said it would soon start accepting cryptocurrencies, including Bitcoin, Ethereum, Bitcoin Cash, and Litecoin, through its online payment system.\r… [+3849 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': "Glassnode: Ethereum users paid $57.5M in transaction fees in October, down from September's record of $166.4M, amid a drop in the volume of DeFi transactions (Omkar Godbole/CoinDesk)",
#    'description': "Omkar Godbole / CoinDesk:\nGlassnode: Ethereum users paid $57.5M in transaction fees in October, down from September's record of $166.4M, amid a drop in the volume of DeFi transactions\xa0 —\xa0 Miners' income from processing transactions on the Ethereum blockchain …",
#    'url': 'https://www.techmeme.com/201103/p7',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/08/piles-of-coins-1200x628.jpg',
#    'publishedAt': '2020-11-03T16:55:01Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Intercoin.org'},
#    'author': None,
#    'title': 'Voting and Governance by Smart Contract',
#    'description': 'Where we are  Earlier this year, we published an article in CoinDesk about using crypto to secure our elections. You can read and discuss more on this forum in part 1 and part 2 that go into some detail about how crypto-powered voting would work, and why it w…',
#    'url': 'https://forum.intercoin.org/t/intercoin-defi-votingcontract-and-governance/1160',
#    'urlToImage': 'https://forum.intercoin.org/uploads/default/original/1X/2aee375a088673f82029cc18542d8a07c9ec2e0a.png',
#    'publishedAt': '2020-10-18T07:04:04Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Next week the Talent Land Latin America will be held',
#    'description': 'The event will be held from November 9 to 12 totally online.',
#    'url': 'https://www.entrepreneur.com/article/359196',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1604696368-Talent-Land-Latam.jpg',
#    'publishedAt': '2020-11-06T21:03:26Z',
#    'content': 'November\r\n6, 2020\r\n4 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\n<ul><li>The event will be presented from November 9 t… [+3065 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Kenny Au',
#    'title': 'Lessons from the Recent KuCoin $150 Million Crypto Hack Incident',
#    'description': 'Is abandoning hot wallets the answer? Not so fast.',
#    'url': 'https://www.entrepreneur.com/article/357172',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1602508982-GettyImages-1125274914.jpg',
#    'publishedAt': '2020-10-13T19:10:00Z',
#    'content': 'October\r\n13, 2020\r\n7 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nEven as the crypto industry has gained traction, many digital currency exchanges are still vulnerable to… [+8425 chars]'},
#   {'source': {'id': None, 'name': 'Marginalrevolution.com'},
#    'author': 'Tyler Cowen',
#    'title': 'What should I answer Vitalik Buterin?',
#    'description': 'Not a CWT, as he will be interviewing me, but likely a discussion too, who knows what I may fling back at him? What do you all recommend I read to prepare?\xa0 I prepared a great deal for my CWT with Vitalik a few years ago (one of my favorite episodes), but wha…',
#    'url': 'https://marginalrevolution.com/marginalrevolution/2020/10/what-should-i-answer-vitalik-buterin.html',
#    'urlToImage': 'https://marginalrevolution.com/wp-content/uploads/2016/10/MR-logo-thumbnail.png',
#    'publishedAt': '2020-10-13T14:30:37Z',
#    'content': 'Not a CWT, as he will be interviewing me, but likely a discussion too, who knows what I may fling back at him?\r\nWhat do you all recommend I read to prepare?\xa0 I prepared a great deal for my CWT with V… [+195 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Matthew Finestone',
#    'title': 'Ethereum-Enhancers Not Ethereum-Killers',
#    'description': 'The new competitive arena in the so-called scaling wars is between Ethereum-enhancers, not Ethereum-killers.',
#    'url': 'https://www.coindesk.com/?p=533818',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/07/ethereum-art-1200x628.jpg',
#    'publishedAt': '2020-10-14T08:00:00Z',
#    'content': 'Ethereum’s popularity has congested the network like never before, and scalability is top of mind. Historically, and still today, many look beyond Ethereum for more scalable smart contract platforms.… [+7723 chars]'},
#   {'source': {'id': None, 'name': 'MSPoweruser'},
#    'author': 'Pradeep',
#    'title': 'PayPal will allow customers to buy, sell and hold cryptocurrencies including Bitcoin and Litecoin',
#    'description': 'PayPal, a leading digital payment provider, today announced that it will allow customers to buy, hold and sell cryptocurrency directly from their PayPal account. Initially, PayPal will support Bitcoin, Ethereum, Bitcoin Cash and Litecoin, directly within the …',
#    'url': 'https://mspoweruser.com/paypal-cryptocurrencies-bitcoin/',
#    'urlToImage': 'https://mspoweruser.com/wp-content/uploads/2015/03/paypal.jpg',
#    'publishedAt': '2020-10-21T13:10:31Z',
#    'content': 'PayPal, a leading digital payment provider, today announced that it will allow customers to buy, hold and sell cryptocurrency directly from their PayPal account. Initially, PayPal will support Bitcoi… [+1804 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Sarah Austin',
#    'title': 'Cutting-Edge Online Financial Strategies for the General Population',
#    'description': 'The future of financial learning is online, centered around digital classrooms.',
#    'url': 'https://www.entrepreneur.com/article/358750',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1604502345-GettyImages-1213513755.jpg',
#    'publishedAt': '2020-11-07T10:30:00Z',
#    'content': 'November\r\n7, 2020\r\n5 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nTraditionally, financial education was\xa0a privilege, reserved almost exclusively for a select few. Those … [+5844 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Sarah Austin',
#    'title': "What's Next for PayPal After Integrating Cryptocurrencies?",
#    'description': 'The online-transaction giant has launched a new service enabling users to buy, hold and sell digital assets. Mainstream adoption might follow.',
#    'url': 'https://www.entrepreneur.com/article/358364',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1603739810-GettyImages-1229220331.jpg',
#    'publishedAt': '2020-10-28T13:00:00Z',
#    'content': 'October\r\n28, 2020\r\n4 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nThe cryptocurrency sector went into a tailspin last week as news reports finally confirmed long-running … [+4480 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Alex Smith',
#    'title': 'The Ledger Nano S crypto hardware wallet is down to $40 for Prime Day',
#    'description': "Amazon is treating Prime members to an onslaught of deals now that it's officially Prime Day. One discount could score you the Ledger Nano S crypto hardware wallet for just $39.99. That marks the best price this model has ever reached on Amazon and saves you …",
#    'url': 'https://www.windowscentral.com/ledger-nano-s-crypto-hardware-wallet-down-40-prime-day',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/ledger-nano-s-6he9-6he9-6he9.jpg',
#    'publishedAt': '2020-10-14T18:31:29Z',
#    'content': "Amazon is treating Prime members to an onslaught of deals now that it's officially Prime Day. One discount could score you the Ledger Nano S crypto hardware wallet for just $39.99. That marks the bes… [+1487 chars]"},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Emily Bary',
#    'title': ': PayPal will let customers buy cryptocurrencies and use them for online payments',
#    'description': 'PayPal Holdings Inc. plans to allow customers to buy cryptocurrency through their accounts and use cryptocurrency for merchant payments.',
#    'url': 'https://www.marketwatch.com/story/paypal-will-let-customers-buy-cryptocurrencies-and-use-them-for-online-payments-11603283352',
#    'urlToImage': 'https://images.mktw.net/im-247725/social',
#    'publishedAt': '2020-10-21T12:29:00Z',
#    'content': 'PayPal Holdings Inc. plans to allow customers to buy cryptocurrency through their accounts and use cryptocurrency for merchant payments. The company announced Wednesday that it is introducing a way f… [+2050 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Joseph Young, Contributor, \n Joseph Young, Contributor\n https://www.forbes.com/sites/youngjoseph/',
#    'title': 'Weird Market Dynamics: 3 Reasons Ethereum Is Dropping While Bitcoin Rallies',
#    'description': 'The current market dynamics are uncanny because Bitcoin has been solely increasing in price, while Ethereum the cryptocurrency market stagnate.',
#    'url': 'https://www.forbes.com/sites/youngjoseph/2020/10/20/weird-market-dynamics-3-reasons-ethereum-is-dropping-while-bitcoin-rallies/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f8fae61767c5d5826a928ab%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D5000%26cropY1%3D464%26cropY2%3D3276',
#    'publishedAt': '2020-10-21T03:44:38Z',
#    'content': 'The price of Bitcoin (BTC) has been rallying strongly while Ethereum (ETH) and other large-cap alternative cryptocurrencies (altcoins) have slumped. In previous bull cycles, ETH front ran BTC, not th… [+3320 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Joseph Young, Contributor, \n Joseph Young, Contributor\n https://www.forbes.com/sites/youngjoseph/',
#    'title': "Whales Offload: Ethereum Crashes 4% In 4 Hours—What's Behind The Drop?",
#    'description': 'The price of Ethereum (ETH), the second-largest cryptocurrency valued at $43 billion, declined by 4% in 4 hours.',
#    'url': 'https://www.forbes.com/sites/youngjoseph/2020/11/02/whales-offload-ethereum-crashes-4-in-4-hours-whats-behind-the-drop/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5fa0bb94fa6a5e473a1f3b6b%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D5100%26cropY1%3D259%26cropY2%3D3127',
#    'publishedAt': '2020-11-03T02:09:21Z',
#    'content': 'The price of Ethereum (ETH), the second-largest cryptocurrency valued at $43 billion, declined by 4% in 4 hours. The steep drop followed a whale moving 4,000 ETH to Binance 20 minutes before a market… [+3063 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Michael Garbade',
#    'title': 'High Gas Fees Prevent Ethereum From Being Ethereum',
#    'description': "Miners are incentivized to keep Ethereum gas fees high, and in doing so, limit one of the network's principal use cases.",
#    'url': 'https://www.coindesk.com/high-gas-fees-prevent-ethereum-from-being-ethereum',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/markus-spiske-o8IfF0RUTTs-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-14T14:42:57Z',
#    'content': 'High Ethereum gas prices make it impossible for ERC-20 projects to run any microtransaction payments on Ethereum. This defeats the idea of using the Ethereum network for one of its principal use case… [+6990 chars]'},
#   {'source': {'id': None, 'name': 'Codementor.io'},
#    'author': 'Gabriel Saldanha',
#    'title': 'Codementor: [Part 1/2] Deploy a Smart Contract on Ethereum with Python, Truffle and web3py',
#    'description': "In this tutorial, we'll write a simple smart contract, deploy it to a personal Ethereum blockchain, and call the contract from a Python script.",
#    'url': 'https://www.codementor.io/@gcrsaldanha/part-1-2-deploy-a-smart-contract-on-ethereum-with-python-truffle-and-web3py-1buhsxibhf',
#    'urlToImage': 'https://s3.amazonaws.com/codementor_assets/assets/community_banner.png',
#    'publishedAt': '2020-11-06T01:58:21Z',
#    'content': "In this tutorial, we'll write a simple smart contract, deploy it to a personal Ethereum blockchain, and call the contract from a Python script.\r\nWhat you need to have installed before we proceed:\r\n<u… [+5348 chars]"},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Ian Allison',
#    'title': 'Ethereum’s Vitalik Buterin Calls on Power Users to Move to Layer 2 Scaling',
#    'description': 'Talking at CoinDesk\'s invest: ethereum economy event, the Ethereum founder called for users of the second-largest blockchain to move over to scaling solutions that are “already here."',
#    'url': 'https://www.coindesk.com/ethereum-vitalik-buterin-layer-2-scaling',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2018/12/DEVCON-2018-PRAGUE-02977-1200x628.jpg',
#    'publishedAt': '2020-10-14T15:37:30Z',
#    'content': 'In the face of Ethereums recent rocketing transaction fees, its founder and chief scientist, Vitalik Buterin, called on users of the second-largest blockchain to move over to scaling solutions that a… [+3817 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Joseph Young, Contributor, \n Joseph Young, Contributor\n https://www.forbes.com/sites/youngjoseph/',
#    'title': 'Ethereum Miners Have Been Selling—But There’s A Positive Catch For ETH',
#    'description': 'Ethereum miners are selling across cryptocurrency exchanges, and ETH has noticeably stagnated against Bitcoin. But there are potential catalysts on the horizon.',
#    'url': 'https://www.forbes.com/sites/youngjoseph/2020/10/27/ethereum-miners-have-been-selling-but-theres-a-positive-catch-for-eth/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f97de61d748d3c0c8d94a4c%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D6240%26cropY1%3D49%26cropY2%3D3559',
#    'publishedAt': '2020-10-27T08:48:25Z',
#    'content': 'According to various on-chain data, Ethereum miners are selling across cryptocurrency exchanges. The trend has been evident in the price of the ETH, which has noticeably stagnated against Bitcoin.\r\nT… [+3351 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Michael del Castillo, Forbes Staff, \n Michael del Castillo, Forbes Staff\n https://www.forbes.com/sites/michaeldelcastillo/',
#    'title': 'How To Track Official Election Results On Ethereum And EOS',
#    'description': 'Ethereum and EOS blockchains are being used by the Associated Press to prove the results their using are official at any given time.',
#    'url': 'https://www.forbes.com/sites/michaeldelcastillo/2020/11/03/how-to-track-official-election-results-on-ethereum-and-eos/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5fa18366de4e85b5f17ce80a%2F0x0.jpg',
#    'publishedAt': '2020-11-03T16:46:39Z',
#    'content': 'The official U.S. election results posted by the Associated Press will use two different blockchains to prove the results at any given time are official.\r\nAFP via Getty Images\r\nFor the first time eve… [+3354 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Steven Ehrlich, Forbes Staff, \n Steven Ehrlich, Forbes Staff\n https://www.forbes.com/sites/stevenehrlich/',
#    'title': 'Leading ‘Privacy Coin’ Zcash Poised For Growth Following Placement On Ethereum',
#    'description': 'Through a process known as ‘wrapping’, a synthetic version of zcash is now available on Ethereum that is compatible with all of its major wallets and applications.',
#    'url': 'https://www.forbes.com/sites/stevenehrlich/2020/10/29/leading-privacy-coin-zcash-poised-for-growth-following-placement-on-ethereum/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f9ac7decdca5829bbe6c2de%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D5183%26cropY1%3D263%26cropY2%3D3179',
#    'publishedAt': '2020-10-29T13:48:46Z',
#    'content': 'Combination locks inbuilt to sections of a hexagonal jigsaw puzzle which are interconnected of each other. 3D rendering graphics on the subject of Modern Digital Technologies.\r\ngetty\r\nAs well as bitc… [+7027 chars]'},
#   {'source': {'id': None, 'name': 'Upstract.com'},
#    'author': 'editors',
#    'title': 'Why Bitcoin price and volume rising together is bad news for Ethereum, altseason',
#    'description': 'Bitcoin broke out of the $13,000 resistance level merely a week ago while Ethereum, altcoins have been lagging behind',
#    'url': 'https://upstract.com/p/sbhb2rbq?ref=rss&rd=1',
#    'urlToImage': 'https://cdn.upstract.com/p/p9qet8SsMZUTKEKeW55o/sbhb2rbq/ywrgimy826_t.jpg',
#    'publishedAt': '2020-10-31T09:05:20Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'John Navin, Contributor, \n John Navin, Contributor\n https://www.forbes.com/sites/johnnavin/',
#    'title': 'Bitcoin, Ethereum And XRP: Now What? An Analysis Of Price',
#    'description': 'The Bitcoin weekly chart seems to send a similar message: After making it all the way back up to the mid-2019 high up around 14000, the price pulled back to the lower end of the weekly range.',
#    'url': 'https://www.forbes.com/sites/johnnavin/2020/10/28/bitcoin-ethereum-and-xrp-now-what-an-analysis-of-price/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f99f1c33942f901b26d4c35%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D7952%26cropY1%3D0%26cropY2%3D4470',
#    'publishedAt': '2020-10-28T22:42:57Z',
#    'content': 'Physical version of Bitcoin and dollar banknotes. Exchange bitcoin for a dollar symbol. Conceptual ... [+] image for worldwide cryptocurrency and digital payment system.\r\ngetty\r\nBitcoin finally close… [+3620 chars]'},
#   {'source': {'id': None, 'name': 'Codementor.io'},
#    'author': 'Gabriel Saldanha',
#    'title': 'Codementor: [Part 2/2] Persist data to the Ethereum blockchain using Python, Truffle, and Ganache',
#    'description': 'The previous post (https://dev.to/gcrsaldanha/deploy-a-smart-contract-on-ethereum-with-python-truffle-and-web3py-5on) demonstrated how to write a simple smart contract with Solidity and deploy it...',
#    'url': 'https://www.codementor.io/@gcrsaldanha/part-2-2-persist-data-to-the-ethereum-blockchain-using-python-truffle-and-ganache-1bui1s7xyc',
#    'urlToImage': 'https://s3.amazonaws.com/codementor_assets/assets/community_banner.png',
#    'publishedAt': '2020-11-06T01:58:49Z',
#    'content': 'The previous post demonstrated how to write a simple smart contract with Solidity and deploy it to the Ethereum Blockchain.This tutorial will show how to update the contract to save some data in the … [+7348 chars]'},
#   {'source': {'id': None, 'name': 'Visual.ly'},
#    'author': 'smartereumnews',
#    'title': 'Ethereum Classic News',
#    'description': 'Smartereum is an emerging provider of Ethereum and Blockchain ecosystem news. We cover breaking news, announcements, information, and in-depth analyse',
#    'url': 'https://visual.ly/community/Infographics/other/ethereum-classic-news',
#    'urlToImage': 'https://thumbnails-visually.netdna-ssl.com/ethereum-classic-news_5f93151a42035_w250_h250.png',
#    'publishedAt': '2020-10-23T17:38:34Z',
#    'content': 'Smartereum A Social Platform for Cryptocurrency Investors &amp; Traders &amp; Analysts You Can Read about following Cryptocurrencies Bitcoin is a crypto-currency or software that forms a decentalized… [+544 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Cawrey',
#    'title': 'Market Wrap: Bitcoin Tests $12K; Ethereum Fees Fall to 3-Month Low',
#    'description': 'Bitcoin’s price passed $12,000 for the first time since September as Ethereum fees dip.',
#    'url': 'https://www.coindesk.com/market-wrap-bitcoin-tests-12k-ethereum-fees-fall',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/cdbpioct20-1200x628.jpg',
#    'publishedAt': '2020-10-20T20:42:17Z',
#    'content': 'Bitcoins price passed $12,000 for the first time since September as Ethereum fees dipped.\r\n<ul><li>Bitcoin (BTC) trading around $11,910 as of 20:00 UTC (4 p.m. ET). Gaining 1.8% over the previous 24 … [+4567 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Cawrey',
#    'title': 'Market Wrap: Bitcoin Jumps to $14.2K; Ethereum Gas Usage Grows 113% YTD',
#    'description': 'Bitcoin’s price bounced Wednesday as Ethereum transaction fee data shows a DeFi downturn.',
#    'url': 'https://www.coindesk.com/index.php?p=541257',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/11/cdbpinov4-1200x628.jpg',
#    'publishedAt': '2020-11-04T21:29:17Z',
#    'content': 'Bitcoin is making gains during the U.S. presidential election uncertainty while Ethereums gas data is highlighting a DeFi decline.\r\n<ul><li>Bitcoin (BTC) trading around $14,061 as of 21:00 UTC (4 p.m… [+3962 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Cawrey',
#    'title': 'Market Wrap: Bitcoin Falls to $12.7K as Global Equities Falter; Ethereum Fees Continue to Drop',
#    'description': 'Bitcoin’s price took a dive along with most other assets as Ethereum fees continue to dip.',
#    'url': 'https://www.coindesk.com/market-wrap-bitcoin-falls-ethereum-fees-drop-further',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/cdbpioct26-1200x628.jpg',
#    'publishedAt': '2020-10-26T20:26:31Z',
#    'content': 'Bitcoins price fell Monday on larger macroeconomic concerns while lower Ethereum fees benefit hardcore DeFi users.\r\n<ul><li>Bitcoin (BTC) trading around $13,011 as of 20:00 UTC (4 p.m. ET). Slipping … [+3693 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Kuhn',
#    'title': 'Blockchain Bites: Ethereum 2.0’s Deposit Contract Goes Live as ETH Miner Revenues Dwindle',
#    'description': 'Ethereum stakers can now begin depositing the 32 ether (ETH) required to stake on Eth 2.0.',
#    'url': 'https://www.coindesk.com/index.php?p=541130',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/07/ethereum-art-1200x628.jpg',
#    'publishedAt': '2020-11-04T17:37:46Z',
#    'content': 'Predictive markets rollicked with U.S. ballot counting. Two more crypto payments cards are expected to market. Nearly $1 billion worth of BTC moved from a long-dormant wallet potentially connected wi… [+8246 chars]'},
#   {'source': {'id': None, 'name': 'Visual.ly'},
#    'author': 'onlinelearningsingh',
#    'title': 'What are WKX and Ethereum?',
#    'description': 'WKX and Ethereum are both crypto exchanges. They provide many products and services related to the cryptocurrency world.',
#    'url': 'https://visual.ly/community/Infographics/business/what-are-wkx-and-ethereum',
#    'urlToImage': 'https://thumbnails-visually.netdna-ssl.com/what-are-wkx-and-ethereum_5f8a89485184f_w250_h250.jpg',
#    'publishedAt': '2020-10-17T06:03:52Z',
#    'content': 'What are WKX and Ethereum? WKX and Ethereum are both crypto exchanges.They provide many products and services related to the cryptocurrency world. Visit Cryptoknowmics to know how to transfer from WK… [+297 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Camila Russo',
#    'title': 'Ethereum Is Building the Internet of Value',
#    'description': 'The original internet was built without money in mind. The next internet will be different and change, albeit small, is already here.',
#    'url': 'https://www.coindesk.com/ethereum-building-internet-of-value',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/joshua-sortino-LqKhnDzSF-8-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-13T15:15:59Z',
#    'content': 'The internet is at the cusp of entering a new phase, one where entrenched rulers are dethroned, more power is reclaimed by individuals and value moves as freely as cat GIFs.\r\nTo understand why we nee… [+8672 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'William Foxley',
#    'title': 'Ethereum’s Top Dapps Are Increasingly Turning to ‘Rollups’: Here’s Why',
#    'description': 'A majority of the top Ethereum-based decentralized applications (dapps) are switching to rollups, a layer 2 for increasing throughput.',
#    'url': 'https://www.coindesk.com/ethereum-dapps-rollups-heres-why',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/GettyImages-1226079814-1200x628.jpg',
#    'publishedAt': '2020-10-13T18:21:09Z',
#    'content': 'Ethereum scaling solutions are heterogeneous, which, as a result, makes them hard to monitor.\r\nFor those conversational about all things Ethereum, rollups are the newest need-to-know technology that … [+6200 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'William Foxley',
#    'title': 'Validators Drop Off Ethereum 2.0 Testnets as Mainnet Release Looms',
#    'description': 'Participation on both the Zinken and Medalla testnets has fallen as Ethereum developers prepare for the deposit contract’s release.',
#    'url': 'https://www.coindesk.com/ethereum-2-0-testnet-validators-drop',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/Medalla-validators-drop-1200x628.jpg',
#    'publishedAt': '2020-10-20T13:42:39Z',
#    'content': 'If testnet participation is any indication, Ethereum 2.0 validators are itching for the real thing as the network kickoff looms.\r\nOnly 36% of the necessary 66% participants needed to secure the Medal… [+1408 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Nathan DiCamillo',
#    'title': 'Publicly Traded INX Crypto Exchange Acquires Broker-Dealer Openfinance',
#    'description': 'INX Limited, a cryptocurrency exchange that went public on Ethereum last month, agreed to purchase U.S. broker-dealer Openfinance Securities.',
#    'url': 'https://www.coindesk.com/publicly-traded-inx-acquires-broker-dealer-openfinance',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/08/wall-street-1200x628.jpeg',
#    'publishedAt': '2020-10-27T13:50:32Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Palmer',
#    'title': 'Vitalik Buterin Sends $1.4M of Ether in Preparation for Ethereum 2.0 Staking',
#    'description': 'Ethereum founder Vitalik Buterin has sent his first ether for staking on the next iteration of the blockchain network.',
#    'url': 'https://www.coindesk.com/vitalik-buterin-sends-1-4m-of-ether-in-preparation-for-ethereum-2-0-staking',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2018/12/DEVCON-2018-PRAGUE-02969-1200x628.jpg',
#    'publishedAt': '2020-11-06T12:41:52Z',
#    'content': 'Ethereum founder Vitalik Buterin has sent his first ether for staking on the next iteration of the blockchain network.\r\n<ul><li>Buterin\'s "VB2" address sent 100 transactions for 32 ether each, all in… [+1258 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Ian Allison',
#    'title': 'Breitling Goes Live With Ethereum-Based System to Put All New Watches on the Blockchain',
#    'description': 'Breitling is the first luxury watchmaker to offer an Ethereum-based digital passport for all its new timepieces.',
#    'url': 'https://www.coindesk.com/breitling-arianee-all-new-watches-ethereum',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/bence-balla-schottner-_HAVhi9B2a4-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-15T08:16:19Z',
#    'content': 'The actual Breitling watch given to James Bond in the 1965 film Thunderball (it had a built-in Geiger counter) apparently wound up being sold at a car boot sale for £25 ($33). The collectors piece wa… [+3154 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Ian Allison',
#    'title': 'Privacy Coin Zcash Makes Its Ethereum ‘Wrapped’ Debut With Tokensoft and Anchorage',
#    'description': 'WZEC is the first asset to be launched by “Wrapped,” a partnership between Ethereum tokenizers Tokensoft and qualified custodian Anchorage.',
#    'url': 'https://www.coindesk.com/wrapped-zcash-ethereum-tokensoft-anchorage',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2019/12/Mason-Borda2-1200x628.jpg',
#    'publishedAt': '2020-10-21T16:05:54Z',
#    'content': 'Remember when crypto exchanges were strong-armed into delisting privacy coins like zcash (ZEC) in order to protect their brittle banking covenants?\r\nBut crypto keeps moving, and today ZEC is making i… [+4977 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Kuhn',
#    'title': 'Blockchain Bites: Your Guide to Invest Ethereum Economy',
#    'description': "The fully virtual CoinDesk invest: ethereum economy goes live today. Here's everything you need to know about the event.",
#    'url': 'https://www.coindesk.com/blockchain-bites-your-guide-to-invest-ethereum-economy',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/07/ethereum-art-1200x628.jpg',
#    'publishedAt': '2020-10-14T13:36:55Z',
#    'content': 'Invest: ethereum economy, a full day of conversation, workshopping and networking around the future of money, goes live today at\xa09 a.m. ET.\r\nStarting off with a keynote speech from Ethereum co-creato… [+10503 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Sebastian Sinclair',
#    'title': 'If This New Tech Works, You Won’t Need 32 Ether to Earn Staking Rewards',
#    'description': 'Ethereum startup Blox is introducing shared staking pools, allowing users to aggregate their ether holdings to participate in Eth 2.0.',
#    'url': 'https://www.coindesk.com/blox-shared-staking',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2018/09/miniatures-reading-reports-1200x628.jpg',
#    'publishedAt': '2020-10-14T12:30:55Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'William Foxley',
#    'title': 'FTX Looking to List ‘Beacon Chain’ Ether as Deposit Contract Goes Live',
#    'description': 'Exchanges may consider markets for “Beacon chain ether” – that is, ether that’s been staked in the Ethereum 2.0 deposit contract.',
#    'url': 'https://www.coindesk.com/index.php?p=541252',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/11/GettyImages-544669728-1200x628.jpg',
#    'publishedAt': '2020-11-04T22:23:14Z',
#    'content': 'Will an active secondary market emerge for ether (ETH) locked into Ethereum 2.0s deposit contract?\xa0\r\nThats the question on the tip of most every traders tongue Wednesday after the release of the depo… [+2698 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Tim Ogilvie',
#    'title': 'To Stake or No? That’s the Eth 2.0 Question',
#    'description': 'Pioneers in stalking face a tough choice between securing Ethereum 2.0 and the opportunity costs of freezing their assets.',
#    'url': 'https://www.coindesk.com/to-stake-or-not-to-stake-eth-2-question',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/11/MOSHED-2020-11-5-13-55-9-1200x628.jpg',
#    'publishedAt': '2020-11-06T14:30:49Z',
#    'content': 'Now that Ethereum 2.0 is finally set to go live, people face a crucial decision: whether or not to stake. It comes down to balancing the age-old calculus of risk and reward. Ethereum 2.0 holds out th… [+5845 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'William Foxley',
#    'title': 'Ethereum 2.0 Countdown Begins With Release of Deposit Contract',
#    'description': 'Ethereum 2.0’s deposit contract is now live, heralding the imminent unveiling of the "world computer\'s" second act.',
#    'url': 'https://www.coindesk.com/ethereum-2-0-contract-deposit-mainnet',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/02/Vitalik0-1200x628.jpg',
#    'publishedAt': '2020-11-04T15:38:59Z',
#    'content': 'Ethereum 2.0’s deposit contract is now live, heralding the imminent unveiling of the “world computer’s” second act.\r\nReleased at 15:00 UTC, according to developer Afri Schoedon, the deposit contract … [+3735 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Omkar Godbole',
#    'title': 'Ethereum Fees Plummeted 65% in October as DeFi Volumes Fell Back to Earth',
#    'description': "Miners' income from processing transactions on the Ethereum blockchain more than halved in October as the mania for DeFi cooled.",
#    'url': 'https://www.coindesk.com/ethereum-fees-plummeted-65-in-october-as-defi-volumes-fell-back-to-earth',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/08/piles-of-coins-1200x628.jpg',
#    'publishedAt': '2020-11-03T16:18:55Z',
#    'content': 'Miners’ income from processing transactions on the Ethereum blockchain more than halved in October as the mania for decentralized finance (DeFi) cooled.\r\n<ul><li>Ethereum users paid $57.49 million in… [+1587 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Sebastian Sinclair',
#    'title': 'Gemini Exchange Building ‘Wrapped Filecoin’ for the Ethereum Network',
#    'description': "Cryptocurrency exchange Gemini is working to bring decentralized storage platform Filecoin's native FIL token to the Ethereum network.",
#    'url': 'https://www.coindesk.com/gemini-exchange-building-wrapped-filecoin-for-the-ethereum-network',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2018/05/shutterstock_632532662-e1526441836104-1200x628.jpg',
#    'publishedAt': '2020-11-10T13:56:17Z',
# ...
#    'url': 'https://www.coindesk.com/?p=533922',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/Screen-Shot-2020-10-13-at-7.45.54-PM.png',
#    'publishedAt': '2020-10-14T17:30:01Z',
#    'content': 'Cryptocurrency exchange Binance’s latest experiment to integrate decentralized finance with its centralized platform, Binance Smart Chain, is not here to beat DeFi, said the companys CEO, Changpeng “… [+3537 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Edan Yago',
#    'title': 'Forget Ethereum, DeFi Is Being Built on Bitcoin',
#    'description': 'Responding to an earlier op-ed, Edan Yago argues that Bitcoin is the past, present and future of decentralized finance.',
#    'url': 'https://www.coindesk.com/?p=536903',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/hans-veth-YGMyrU2sjUk-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-22T12:00:40Z',
#    'content': 'A few weeks ago a CoinDesk headline,”Why Hardnosed Bitcoiners Can Learn to Love DeFi,” caught my eye. The title was designed for controversy. Decentralized finance\xa0(DeFi) seems to be everything Bitco… [+3870 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Christopher Brookins, Contributor, \n Christopher Brookins, Contributor\n https://www.forbes.com/sites/christopherbrookins/',
#    'title': 'Bitcoin Is Taking A Breather, But Don’t Panic',
#    'description': 'Stories like Square and Stone Ridge have become common place in 2020, which is why bitcoin’s fundamentals have continued to shine bullish.',
#    'url': 'https://www.forbes.com/sites/christopherbrookins/2020/10/13/bitcoin-is-taking-a-breather-but-dont-panic/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f85ee3475fcc9cd28b32ef3%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D5200%26cropY1%3D514%26cropY2%3D2952',
#    'publishedAt': '2020-10-13T18:48:54Z',
#    'content': 'Bitcoin is taking a breather, but no worries at this time.\r\ngetty\r\nLast week, Square \r\n SQ\r\n, surprise announced that they had put 1% of their firms assets into bitcoin. Since then, bitcoin is up ~8%… [+2264 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Ian Allison',
#    'title': 'Securitize Is Taking Ethereum-Based Securities Into the DeFi Realm',
#    'description': 'Securitize is teaming with a protocol called Tinlake from Centrifuge, which uses a clever system of NFTs to put real-world assets into DeFi.',
#    'url': 'https://www.coindesk.com/securitize-tinlake-centrifuge-ethereum-based-securities-defi',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2019/09/Carlos-Domingo-Securitize-1200x628.jpg',
#    'publishedAt': '2020-10-12T16:30:54Z',
#    'content': 'Connecting the worlds of security tokens and decentralized finance (DeFi) is the next logical step for Securitize, a kind of regulatory-compliant fixer when it comes to tracking and trading blockchai… [+4244 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Frances Coppola',
#    'title': 'Ethereum, Dark Forests and the Limits of Transparency',
#    'description': 'The crypto world eschewed trust in favor of transparency. But transparency doesn’t solve the problem of untrustworthiness in financial markets.',
#    'url': 'https://www.coindesk.com/ethereum-dark-forests-limits-of-transparency',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/krystian-piatek-JUqXOPOYXEg-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-28T16:54:49Z',
#    'content': 'The mempool is a dark forest, proclaims Ryan Sean Adams, author of the Bankless newsletter. And he goes on to paint a picture of a dangerous place full of predators arbitrage bots, front-runners and … [+7284 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Danny Nelson',
#    'title': 'Grayscale’s Ethereum Trust Granted SEC Reporting Company Status',
#    'description': 'Institutional bitcoin investors are looking "how else they can diversify within the asset class," said Michael Sonnenshein.',
#    'url': 'https://www.coindesk.com/grayscales-ethereum-trust-granted-sec-reporting-company-status',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2019/11/2019-11-12-09.58.22-1200x628.jpg',
#    'publishedAt': '2020-10-12T13:30:42Z',
#    'content': 'Grayscale Investments Ethereum Trust on Monday became a Securities and Exchange Commission (SEC) reporting company, a move that increases the trusts transparency and potentially its liquidity too.\r\n<… [+859 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Ian Allison',
#    'title': 'Ocean V3 Brings Wave of Data Monetization Tools to Ethereum',
#    'description': 'A third version of Ocean Protocol has been released, fleshing out its vision for “datatokens” and decentralized data marketplaces.',
#    'url': 'https://www.coindesk.com/?p=538279',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/miguel-a-amutio-tM7xRyaL-4M-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-27T08:00:00Z',
#    'content': 'A third and all-encompassing version of Ocean Protocol has been released, fleshing out its vision for datatokens and decentralized data marketplaces.\r\nAnnounced Tuesday, Ocean v3 brings the Ocean dat… [+5399 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Brady Dale',
#    'title': 'Will a Sharded Ethereum Be Flexible Enough for Decentralized Finance?',
#    'description': "Over the past year composability has become a very real competitive advantage for DeFi. Will Ethereum's upcoming overhaul threaten it?",
#    'url': 'https://www.coindesk.com/ethereum-2-0-sharding-defi-composability',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/henrik-hjortshoj-lEwyj4FiHHU-unsplash-1200x628.jpg',
#    'publishedAt': '2020-10-13T18:46:03Z',
#    'content': '“Money legos” might be an apt metaphor for what decentralized finance (DeFi) does, but since the summer another one has applied: jackpot.\r\nMoney legos is the term used to describe the way Ethereum al… [+8467 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Ben Edgington',
#    'title': 'It’s Time to Launch the Ethereum 2.0 Beacon Chain',
#    'description': "We've spent the last nine months testing the life out of this thing. It's time to stake our ideas, money and time on the line.",
#    'url': 'https://www.coindesk.com/time-to-launch-ethereum-2-beacon-chain',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/10/MOSHED-2020-10-9-16-23-0-1200x628.jpg',
#    'publishedAt': '2020-10-12T12:16:56Z',
#    'content': 'Its time for the Ethereum 2.0 beacon chain to launch.\r\nWe’ve spent the last nine months testing the life out of this thing. The year began with huge, long-running single client testnets: Sapphire, To… [+6735 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – October 29th, 2020',
#    'description': 'It’s a mixed start to the day for the majors. Failure to move through the day’s pivot levels would bring the major support levels into play.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-001239619.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/VtuuXO.Iyc16lsI1Yy4fcQ--~B/aD00MTA7dz02MTU7c209MTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/fx_empire_176/7f66e12f3de32779e1aa4946c495e539',
#    'publishedAt': '2020-10-29T00:12:39Z',
#    'content': 'Ethereum\r\nEthereum slid by 4.22% on Wednesday. Reversing a 3.22% gain from Tuesday, Ethereum ended the day at $388.63.\r\nIt was a bullish start to the day. Ethereum rose to an early morning intraday h… [+5573 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Nicholas Gans, Contributor, \n Nicholas Gans, Contributor\n https://www.forbes.com/sites/nicholasgans/',
#    'title': 'DeFi Tokens Tumble But Fundamentals Remain At All-Time High',
#    'description': "While many 'DeFi Degens' have been washed out by plummeting token prices, these fundamentals appear strong in decentralized finance broadly.",
#    'url': 'https://www.forbes.com/sites/nicholasgans/2020/10/30/defi-tokens-tumble-but-fundamentals-remain-at-all-time-high/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f9c493162854ea5ee2e0c4d%2F0x0.jpg',
#    'publishedAt': '2020-10-30T23:11:53Z',
#    'content': 'Asset prices in the DeFi space have plummeted since their recent highs. The DeFi Index Perpetual Futures instrument on FTX, which tracks a basket of DeFi assets, is down almost 50% from its high on S… [+3375 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Frances Coppola',
#    'title': 'Ethereum, Dark Forests and the Limits of Transparency',
#    'description': 'The crypto world eschewed trust in favor of transparency. But transparency doesn’t solve the problem of untrustworthiness in financial markets.',
#    'url': 'https://finance.yahoo.com/news/ethereum-dark-forests-limits-transparency-165449696.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/..7xGgeZ1X6Eeq7h5v9DxA--~B/aD05NDc7dz0xNDIwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/coindesk_75/5b68339353ca80ee52293adc4090d2a8',
#    'publishedAt': '2020-10-28T16:54:49Z',
#    'content': '“The mempool is a dark forest,” proclaims Ryan Sean Adams, author of the “Bankless” newsletter. And he goes on to paint a picture of a dangerous place full of predators – arbitrage bots, front-runner… [+7669 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Bitcoin and Ethereum – Weekly Technical Analysis – November 2nd, 2020',
#    'description': 'It’s a choppy start to the week for the majors. Steering clear of the week’s pivot levels would bring resistance levels into play, however.',
#    'url': 'https://finance.yahoo.com/news/bitcoin-ethereum-weekly-technical-analysis-040146287.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/4qUf3bvArf9PG8VTkhlAcQ--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/db16b86289f35f6b300e56426233deac',
#    'publishedAt': '2020-11-02T04:01:46Z',
#    'content': 'Wall Street hit some rough waters last week. With the Presidential elections only two days away, spiking COVID-19 numbers and hopes for a pre-election stimulus package dwindling, stocks posted their … [+10447 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – October 24th, 2020',
#    'description': 'It’s a bearish start to the day for the majors. Failure to move through the day’s pivot levels would bring support levels into play.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-003143490.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/XJFg38r6YqSz1SK0G.U4KA--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/2c7369042340db765c8bd715a6452bbc',
#    'publishedAt': '2020-10-24T00:31:43Z',
#    'content': 'Ethereum\r\nEthereum fell by 1.23% on Friday. Partially reversing a 5.96% rally from Thursday, Ethereum ended the day at $409.52.\r\nIt was a mixed start to the day. Ethereum rose to a late morning intra… [+5327 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Sarah Austin',
#    'title': 'Why Trust and Incentives Help Consumers With Better Brand Selection',
#    'description': "More than 90 percent of people trust family and friends' brand recommendations. Just 38 percent trust info from advertisers.",
#    'url': 'https://www.entrepreneur.com/article/357871',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1604330828-GettyImages-1155921165.jpg',
#    'publishedAt': '2020-11-03T10:30:00Z',
#    'content': 'November\r\n3, 2020\r\n9 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nTrust and loyalty rewards have underpinned U.S. consumer spending for decades. Trust makes it easy to do… [+10274 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Jaspreet Kalra',
#    'title': 'Kadena Partners With Stablecoin-Maker Terra in Bid to Expand Its DeFi Offering',
#    'description': 'The hybrid blockchain maker, Kadena, announced on Tuesday that it has partnered with Terra and will be adding Terra’s stablecoin Luna to its decentralized exchange (DEX) Kadenswap.',
#    'url': 'https://www.coindesk.com/kadena-partners-with-stablecoin-maker-terra-in-bid-to-expand-its-defi-offering',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/01/Stuart-Popejoy-speaks-at-Construct-2017-1200x628.jpg',
#    'publishedAt': '2020-11-10T16:00:31Z',
#    'content': 'Hybrid blockchain platform Kadena is teaming up with stablecoin maker Terra with the aim of expanding its decentralized finance (DeFi) platform.\xa0\r\nAnnounced on Tuesday, Kadena said that it will add T… [+1313 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – November 7th, 2020',
#    'description': 'It’s a bullish start to the day for the majors. Avoiding the day’s pivot levels would support another day of gains.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-001312870.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/o4nu6uwLbX8sQpSMQzUETw--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/fd54299d171ad9a55e5f7719211245b0',
#    'publishedAt': '2020-11-07T00:13:12Z',
#    'content': 'Ethereum\r\nEthereum surged by 9.43% on Friday. Following on from a 3.47% rally on Thursday, Ethereum ended the day at $456.65.\r\nIt was a particularly bullish day. Ethereum rallied from an early mornin… [+5484 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Sebastian Sinclair',
#    'title': 'Ethereum Classic’s MESS Solution Won’t Provide ‘Robust’ Security Against 51% Attacks: Report',
#    'description': 'A solution being implemented to safeguard against so-called 51% attacks on the Ethereum Classic (ETC) network may not be as secure as suggested, according to a new analysis.',
#    'url': 'https://www.coindesk.com/ethereum-classic-mess-security-51-attacks-report',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2016/07/shutterstock_51817135-1200x628.jpg',
#    'publishedAt': '2020-10-21T14:29:53Z',
#    'content': 'A solution being implemented to safeguard against so-called 51% attacks on the Ethereum Classic (ETC) network may not be as secure as other alternatives, according to a new analysis.\r\nThis summer, th… [+2375 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Aislinn Keely',
#    'title': 'Grayscale’s Ethereum Trust joins GBTC as SEC-registered reporting company',
#    'description': "Grayscale's Ethereum Trust is now a registered reporting company with the Securities and Exchange Commission (SEC).The post Grayscale's Ethereum Trust joins GBTC as SEC-registered reporting company appeared first on The Block.",
#    'url': 'https://finance.yahoo.com/news/grayscale-ethereum-trust-joins-gbtc-211422661.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/71CImNSyMZ5YjYjQLS6Hew--~B/aD00NTA7dz04MDA7c209MTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en-US/the_block_83/e2e170e7e03a29b9e9ab2efb6c3d7d10',
#    'publishedAt': '2020-10-12T21:14:22Z',
#    'content': "Grayscale's Ethereum Trust is now a registered reporting company with the Securities and Exchange Commission (SEC).\r\nThe Form 10 filing for the Grayscale Ethereum Trust took effect today, meaning it … [+1504 chars]"}]}

# %% [markdown]
# ## Create dataframe for both Bitcoin and Ethereum articles

# %%
bitcoin_df = pd.DataFrame.from_dict(bitcoin_headlines["articles"])

bitcoin_df.head()
# Out:
#                                        source          author  \
# 0  {'id': 'techcrunch', 'name': 'TechCrunch'}   Romain Dillet
# 1  {'id': 'techcrunch', 'name': 'TechCrunch'}  Zack Whittaker
# 2    {'id': 'the-verge', 'name': 'The Verge'}      Nick Statt
# 3         {'id': None, 'name': 'Gizmodo.com'}      John Biggs
# 4      {'id': 'engadget', 'name': 'Engadget'}        Engadget
#
#                                                title  \
# 0  PayPal to let you buy and sell cryptocurrencie...
# 1  DOJ says it seized over $1 billion in bitcoin ...
# 2  PayPal and Venmo will offer and accept cryptoc...
# 3  Bitcoin Mixer Designed to Bypass Money Launder...
# 4  The Morning After: Xbox Series X and Series S ...
#
#                                          description  \
# 0  PayPal has partnered with cryptocurrency compa...
# 1  Two days ago, about $1 billion worth of bitcoi...
# 2  PayPal is joining the cryptocurrency industry ...
# 3  The Financial Crimes Enforcement Network (FinC...
# 4  2018’s jokes are 2020’s reality. I’m speaking,...
#
#                                                  url  \
# 0  http://techcrunch.com/2020/10/21/paypal-to-let...
# 1  http://techcrunch.com/2020/11/05/justice-depar...
# 2  https://www.theverge.com/2020/10/21/21527288/p...
# 3  https://gizmodo.com/bitcoin-mixer-designed-to-...
# 4  https://www.engadget.com/xbox-series-review-tm...
#
#                                           urlToImage           publishedAt  \
# 0  https://techcrunch.com/wp-content/uploads/2020...  2020-10-21T13:28:15Z
# 1  https://techcrunch.com/wp-content/uploads/2020...  2020-11-05T17:17:41Z
# 2  https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpb...  2020-10-21T19:49:27Z
# 3  https://i.kinja-img.com/gawker-media/image/upl...  2020-10-20T15:40:00Z
# 4  https://o.aolcdn.com/images/dims?resize=1200%2...  2020-11-06T12:15:01Z
#
#                                              content
# 0  PayPal has partnered with cryptocurrency compa...
# 1  Two days ago, about $1 billion worth of bitcoi...
# 2  PayPal is rolling out cryptocurrency support l...
# 3  The Financial Crimes Enforcement Network (FinC...
# 4  2018’s jokes are 2020’s reality. I’m speaking,...

# %%
ethereum_df = pd.DataFrame.from_dict(Ethereum_headlines["articles"])

ethereum_df.head()
# Out:
#                                               source          author  \
# 0         {'id': 'techcrunch', 'name': 'TechCrunch'}   Romain Dillet
# 1         {'id': 'techcrunch', 'name': 'TechCrunch'}   Romain Dillet
# 2           {'id': 'the-verge', 'name': 'The Verge'}      Nick Statt
# 3  {'id': 'business-insider', 'name': 'Business I...  Reed Alexander
# 4               {'id': 'reuters', 'name': 'Reuters'}            None
#
#                                                title  \
# 0  PayPal to let you buy and sell cryptocurrencie...
# 1  Luxury watch maker Breitling issues digital ce...
# 2  PayPal and Venmo will offer and accept cryptoc...
# 3  The world's largest digital currency asset man...
# 4  Australia's central bank launches digital curr...
#
#                                          description  \
# 0  PayPal has partnered with cryptocurrency compa...
# 1  Breitling is partnering with Arianee to issue ...
# 2  PayPal is joining the cryptocurrency industry ...
# 3  Summary List Placement\n\nPortions of the glob...
# 4  Australia's central bank launches digital curr...
#
#                                                  url  \
# 0  http://techcrunch.com/2020/10/21/paypal-to-let...
# 1  http://techcrunch.com/2020/10/15/luxury-watch-...
# 2  https://www.theverge.com/2020/10/21/21527288/p...
# 3  https://www.businessinsider.com/grayscale-inve...
# 4  https://www.reuters.com/article/us-australia-r...
#
#                                           urlToImage           publishedAt  \
# 0  https://techcrunch.com/wp-content/uploads/2020...  2020-10-21T13:28:15Z
# 1  https://techcrunch.com/wp-content/uploads/2020...  2020-10-15T09:44:51Z
# 2  https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpb...  2020-10-21T19:49:27Z
# 3  https://i.insider.com/5f861adf91aa9e001880b781...  2020-10-14T13:00:00Z
# 4                                               None  2020-11-01T23:42:00Z
#
#                                              content
# 0  PayPal has partnered with cryptocurrency compa...
# 1  Breitling is partnering with Arianee to issue ...
# 2  PayPal is rolling out cryptocurrency support l...
# 3  Portions of the global economy melted down in ...
# 4  FILE PHOTO: A worker pushing a trolley walks w...

# %% [markdown]
# # Sentiment Analyzer

# %%
import nltk
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vinot\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Bitcoin sentiment analyzer

# %%
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_sent_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_sent_df = bitcoin_sent_df[cols]

bitcoin_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-10-21  PayPal has partnered with cryptocurrency compa...    0.0000
# 1  2020-11-05  Two days ago, about $1 billion worth of bitcoi...    0.2263
# 2  2020-10-21  PayPal is rolling out cryptocurrency support l...    0.6808
# 3  2020-10-20  The Financial Crimes Enforcement Network (FinC...   -0.7184
# 4  2020-11-06  2018’s jokes are 2020’s reality. I’m speaking,...    0.2500
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.049     0.000    0.951
# 2     0.162     0.000    0.838
# 3     0.000     0.154    0.846
# 4     0.059     0.000    0.941

# %% [markdown]
# ## Ethereum sentiment analyzer

# %%
ethereum_sentiments = []

for article in Ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_sent_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_sent_df = ethereum_sent_df[cols]

ethereum_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-10-21  PayPal has partnered with cryptocurrency compa...    0.0000
# 1  2020-10-15  Breitling is partnering with Arianee to issue ...    0.0000
# 2  2020-10-21  PayPal is rolling out cryptocurrency support l...    0.6808
# 3  2020-10-14  Portions of the global economy melted down in ...   -0.4215
# 4  2020-11-01  FILE PHOTO: A worker pushing a trolley walks w...    0.0000
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.162     0.000    0.838
# 3     0.085     0.132    0.783
# 4     0.000     0.000    1.000

# %%
bitcoin_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  97.000000  97.000000  97.000000  97.000000
# mean    0.097703   0.065371   0.044144   0.890485
# std     0.472433   0.071408   0.070904   0.082901
# min    -0.875000   0.000000   0.000000   0.703000
# 25%    -0.102700   0.000000   0.000000   0.831000
# 50%     0.000000   0.060000   0.000000   0.890000
# 75%     0.510600   0.117000   0.077000   0.955000
# max     0.946800   0.297000   0.263000   1.000000

# %%
ethereum_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  93.000000  93.000000  93.000000  93.000000
# mean    0.242218   0.075516   0.016011   0.908495
# std     0.355012   0.081557   0.035616   0.086082
# min    -0.493900   0.000000   0.000000   0.626000
# 25%     0.000000   0.000000   0.000000   0.859000
# 50%     0.202300   0.065000   0.000000   0.922000
# 75%     0.458800   0.109000   0.000000   1.000000
# max     0.946800   0.374000   0.151000   1.000000

# %% [markdown]
# ## Questions

# %% [markdown]
# **Which coin had the highest mean positive score?**

# %% [markdown]
# Ethereum

# %% [markdown]
# **Which coin had the highest compound score?**

# %% [markdown]
# Bitcoin

# %% [markdown]
# **Which coin had the highest positive score?**

# %% [markdown]
# Bitcoin

# %% [markdown]
# # Tokenizer

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
lemmatizer = WordNetLemmatizer()

# %%
def tokenizer(text):
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    # Create a list of the words
    tokens = word_tokenize(re_clean)
    # Convert the words to lowercase
    tokens = [t.lower() for t in tokens]
    # Remove the punctuation
    words = [t.translate(str.maketrans('','')) for t in tokens]
    # Remove the stop words
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]
    # Lemmatize Words into root words
    tokens = ', '.join([lemmatizer.lemmatize(word) for word in words])
    return tokens

# %%
bitcoin_df['tokens'] = bitcoin_df.apply(lambda x : tokenizer(x['description']), axis=1)
bitcoin_df[['description','tokens']]
# Out:
#                                           description  \
# 0   PayPal has partnered with cryptocurrency compa...
# 1   Two days ago, about $1 billion worth of bitcoi...
# 2   PayPal is joining the cryptocurrency industry ...
# 3   The Financial Crimes Enforcement Network (FinC...
# 4   2018’s jokes are 2020’s reality. I’m speaking,...
# ..                                                ...
# 95  Olga Kharif / Bloomberg:\nDOJ says it is suing...
# 96  Bitcoin (BTC) has just passed the $15,500 USD ...
# 97  Distressed patients flood support services aft...
# 98  Police violence prompted latest protests but a...
# 99  Square Inc. shares gained in after-hours tradi...
#
#                                                tokens
# 0   paypal, partnered, cryptocurrency, company, pa...
# 1   two, day, ago, billion, worth, bitcoin, sat, d...
# 2   paypal, joining, cryptocurrency, industry, sup...
# 3   financial, crime, enforcement, network, fincen...
# 4   joke, reality, im, speaking, course, tesla, te...
# ..                                                ...
# 95  olga, kharif, bloombergdoj, say, suing, forfei...
# 96  bitcoin, btc, passed, usd, mark, gaining, clos...
# 97  distressed, patient, flood, support, service, ...
# 98  police, violence, prompted, latest, protest, a...
# 99  square, inc, share, gained, afterhours, tradin...
#
# [100 rows x 2 columns]

# %%
ethereum_df['tokens'] = ethereum_df.apply(lambda x : tokenizer(x['description']), axis=1)
ethereum_df[['description','tokens']]
# Out:
#                                           description  \
# 0   PayPal has partnered with cryptocurrency compa...
# 1   Breitling is partnering with Arianee to issue ...
# 2   PayPal is joining the cryptocurrency industry ...
# 3   Summary List Placement\n\nPortions of the glob...
# 4   Australia's central bank launches digital curr...
# ..                                                ...
# 95  More than 90 percent of people trust family an...
# 96  The hybrid blockchain maker, Kadena, announced...
# 97  It’s a bullish start to the day for the majors...
# 98  A solution being implemented to safeguard agai...
# 99  Grayscale's Ethereum Trust is now a registered...
#
#                                                tokens
# 0   paypal, partnered, cryptocurrency, company, pa...
# 1   breitling, partnering, arianee, issue, new, ki...
# 2   paypal, joining, cryptocurrency, industry, sup...
# 3   summary, list, placementportions, global, econ...
# 4   australia, central, bank, launch, digital, cur...
# ..                                                ...
# 95  percent, people, trust, family, friend, brand,...
# 96  hybrid, blockchain, maker, kadena, announced, ...
# 97  bullish, start, day, major, avoiding, day, piv...
# 98  solution, implemented, safeguard, socalled, at...
# 99  grayscales, ethereum, trust, registered, repor...
#
# [100 rows x 2 columns]

# %% [markdown]
# # NGrams and Frequency Analysis

# %%
import nltk, re, string, collections
from nltk.util import ngrams
from nltk import ngrams
from collections import Counter

# %%
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

def bigram_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = process_text(big_string)
    bigrams = ngrams(processed, n=2)
    top_10 = dict(Counter(bigrams).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['bigram', 'count'])

def word_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = process_text(big_string)
    top_10 = dict(Counter(processed).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
bit_count = bitcoin_df["description"]
bigram_counter(bit_count)
# Out:
#                      bigram  count
# 0        (paypal, holdings)     11
# 1           (holdings, inc)      9
# 2               (buy, sell)      9
# 3           (customer, buy)      8
# 4              (sell, hold)      8
# 5           (virtual, coin)      7
# 6        (digital, payment)      6
# 7        (payment, company)      5
# 8        (us, presidential)      5
# 9  (presidential, election)      5

# %%
eth_count = ethereum_df["description"]
bigram_counter(eth_count)
# Out:
#                      bigram  count
# 0       (bitcoin, ethereum)      6
# 1        (digital, payment)      6
# 2  (cryptocurrency, market)      6
# 3           (customer, buy)      6
# 4        (payment, company)      5
# 5               (buy, sell)      5
# 6        (paypal, holdings)      5
# 7           (holdings, inc)      5
# 8        (invest, ethereum)      5
# 9       (ethereum, economy)      5

# %%
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    # Combine all articles in corpus into one large string
    big_string = ' '.join(tokens)
    processed = process_text(big_string)
    top = dict(Counter(processed).most_common(10))
    return pd.DataFrame(list(top.items()), columns=['word', 'count'])

# %%
tokens = bitcoin_df["description"]
token_count(tokens, N=10)
# Out:
#              word  count
# 0         bitcoin     47
# 1          paypal     26
# 2  cryptocurrency     26
# 3              us     23
# 4            year     18
# 5              ha     15
# 6         company     14
# 7         digital     14
# 8         payment     14
# 9       wednesday     14

# %%
tokens = ethereum_df["description"]
token_count(tokens, N=10)
# Out:
#              word  count
# 0        ethereum     53
# 1         bitcoin     32
# 2  cryptocurrency     20
# 3          paypal     18
# 4              ha     15
# 5         digital     14
# 6          market     12
# 7         company     11
# 8           price     11
# 9      blockchain     11

# %% [markdown]
# # Word Clouds

# %%
from nltk.corpus import stopwords, reuters
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = [20.0, 10.0]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vinot\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
bit_cloud = bitcoin_df["description"]

def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

big_string = ' '.join(bit_cloud)
input_text = process_text(big_string)

wc = WordCloud().generate(input_text)
plt.imshow(wc);

# %%
eth_colud = ethereum_df["description"]

def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

big_string = ' '.join(eth_colud)
input_text = process_text(big_string)

wc = WordCloud().generate(input_text)
plt.title("Ethereum Word Cloud")
plt.imshow(wc);

# %% [markdown]
# # Named Entity Recognition

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
bitcoin_concat = bitcoin_df['description'].str.cat(sep=', ')

# %%
bitcoin_ner = nlp(bitcoin_concat)
bitcoin_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has partnered with cryptocurrency company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paxos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to launch a new service.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  users in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  plans to support
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# …,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two days ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  that had sat dormant since the seizure of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Silk Road
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  marketplace in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the biggest underground drug websites on the dark web, suddenly changed hands. Who took it? Mystery over. It was the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  gover…,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  is joining the cryptocurrency industry with support for bitcoin and other digital currencies, making the digital payments company
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most significant adopters of the technology to date.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  plans to extend support to its money-sending app Ve…,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Financial Crimes Enforcement Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (FinCEN) has assessed a civil penalty of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $60 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  from
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry Dean Harmon
#     <span style="font-size: 0.8em; font-weight: bold;

# %%
from pprint import pprint
pprint([(X.text, X.label_) for X in bitcoin_ner.ents])
# Out:
# [('PayPal', 'ORG'),
#  ('Paxos', 'ORG'),
#  ('PayPal', 'PRODUCT'),
#  ('U.S.', 'GPE'),
#  ('PayPal', 'PRODUCT'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum', 'GPE'),
#  ('Bitcoin Cash', 'PERSON'),
#  ('Lite', 'PERSON'),
#  ('Two days ago', 'DATE'),
#  ('about $1 billion', 'MONEY'),
#  ('bitcoin', 'GPE'),
#  ('the Silk Road', 'FAC'),
#  ('2013', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('U.S.', 'GPE'),
#  ('PayPal', 'PRODUCT'),
#  ('one', 'CARDINAL'),
#  ('PayPal', 'PRODUCT'),
#  ('The Financial Crimes Enforcement Network', 'ORG'),
#  ('$60 million', 'MONEY'),
#  ('Larry Dean Harmon', 'PERSON'),
#  ('Helix and Coin Ninja', 'WORK_OF_ART'),
#  ('first', 'ORDINAL'),
#  ('the United States', 'GPE'),
#  ('2018', 'DATE'),
#  ('2020', 'DATE'),
#  ('Tesla Tequila', 'ORG'),
#  ('April', 'DATE'),
#  ('Elon Musk', 'ORG'),
#  ('Teslaquila', 'WORK_OF_ART'),
#  ('Tesla', 'ORDINAL'),
#  ('one', 'CARDINAL'),
#  ('U.S.', 'GPE'),
#  ('Individual X', 'WORK_OF_ART'),
#  ('years', 'DATE'),
#  ('the Department of Jus', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('3,200', 'MONEY'),
#  ('late 2018', 'DATE'),
#  ('bitcoin', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('Beanie Babies', 'ORG'),
#  ('Rolexes', 'PERSON'),
#  ('PayPal', 'PERSON'),
#  ('$1 billion', 'MONEY'),
#  ('Silk Road', 'ORG'),
#  ('Ross Ulbricht', 'PERSON'),
#  ('this week', 'DATE'),
#  ('Instagram', 'PRODUCT'),
#  ('Nigerians', 'PERSON'),
#  ('Reuters India', 'ORG'),
#  ('Instagram', 'PRODUCT'),
#  ('Nigerians', 'PERSON'),
#  ('Reuters.com', 'ORG'),
#  ('ol><li', 'GPE'),
#  ("Satoshi Nakamoto's", 'FAC'),
#  ('Bitcoin', 'GPE'),
#  ('Bitcoin News', 'ORG'),
#  ('MicroStrategy', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('The Crypto Daily', 'ORG'),
#  ('ol><li', 'PERSON'),
#  ('Bitcoin', 'GPE'),
#  ('Bill Miller', 'PERSON'),
#  ('Bitcoin News', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('15', 'MONEY'),
#  ('PayPal', 'PRODUCT'),
#  ('Coca-Cola', 'ORG'),
#  ('Netflix', 'ORG'),
#  ('Disney', 'ORG'),
#  ('PayPal', 'PRODUCT'),
#  ('PayPal', 'NORP'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('The U.S. Justice Department', 'ORG'),
#  ('Thursday', 'DATE'),
#  ('over $1 billion', 'MONEY'),
#  ('bitcoin', 'GPE'),
#  ('Silk Road', 'FAC'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('BTC', 'ORG'),
#  ('BTSP', 'GPE'),
#  ('more than $14,900', 'MONEY'),
#  ('Thursday', 'DATE'),
#  ('January 2018', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Bitcoin', 'GPE'),
#  ('more than $14,900', 'MONEY'),
#  ('Thursday', 'DATE'),
#  ('January 2018', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Bank of England', 'ORG'),
#  ('Andrew Bailey', 'PERSON'),
#  ('Monday', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('Quibi', 'ORG'),
#  ('PayPal', 'PRODUCT'),
#  ('Netflix', 'PERSON'),
#  ('Daily Crunch', 'WORK_OF_ART'),
#  ('October 21, 2020', 'DATE'),
#  ('app', 'ORG'),
#  ('Jeffrey Katzenberg', 'PERSON'),
#  ('Bank of England', 'ORG'),
#  ('Andrew Bailey', 'PERSON'),
#  ('Monday', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('Earlier this week', 'DATE'),
#  ('nearly a billion dollars', 'MONEY'),
#  ('69,369', 'CARDINAL'),
#  ('BTC', 'ORG'),
#  ('2015', 'DATE'),
#  ('Kim Jong Un', 'PERSON'),
#  ('Eastern European', 'NORP'),
#  ('the coming weeks', 'DATE'),
#  ('US', 'GPE'),
#  ('Venmo', 'GPE'),
#  ('2020', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('morning', 'TIME'),
#  ('Elon Musk', 'WORK_OF_ART'),
#  ('Twitter', 'ORG'),
#  ('The Water Project', 'WORK_OF_ART'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('PayPal Holdings Inc <PYPL.O', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ("PayPal Holdings Inc's", 'ORG'),
#  ('Cryptocurrency', 'ORG'),
#  ('this year', 'DATE'),
#  ('bitcoin', 'GPE'),
#  ('this year', 'DATE'),
#  ('bitcoin', 'GPE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ("PayPal Holdings Inc's", 'ORG'),
#  ('Billionaire', 'GPE'),
#  ('Mike Novogratz', 'PERSON'),
#  ('half', 'CARDINAL'),
#  ('Bitcoin', 'GPE'),
#  ('the weekend', 'DATE'),
#  ('li', 'PERSON'),
#  ('Novogratz', 'PERSON'),
#  ('seven years', 'DATE'),
#  ('IRS', 'ORG'),
#  ('two days', 'DATE'),
#  ('69,369', 'CARDINAL'),
#  ('BTC', 'ORG'),
#  ('2020', 'DATE'),
#  ('Grayscale Investments', 'ORG'),
#  ('Crypto', 'GPE'),
#  ('Ozioma Egemasi', 'ORG'),
#  ('Nigerian', 'NORP'),
#  ('this summer', 'DATE'),
#  ('Twitter', 'ORG'),
#  ('the New York State Department of Financial Services', 'ORG'),
#  ('NYSDFS', 'ORG'),
#  ('Twitter', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('One', 'CARDINAL'),
#  ('The New York Department of Financial Services', 'ORG'),
#  ('July', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('Twitter', 'ORG'),
#  ('Twitter', 'ORG'),
#  ('$37 billion', 'MONEY'),
#  ('li', 'PERSON'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('li', 'PERSON'),
#  ('above $13,000', 'MONEY'),
#  ('Wednesday', 'DATE'),
#  ('the week', 'DATE'),
#  ('PayPal', 'ORG'),
#  ('the Complete Wall Street and Cryptocurrency Trading Bootcamp', 'FAC'),
#  ('30', 'MONEY'),
#  ('Oct. 22', 'DATE'),
#  ('Hong Kong', 'GPE'),
#  ('Tuesday', 'DATE'),
#  ('an era', 'DATE'),
#  ('Jeffrey Toobin', 'PERSON'),
#  ('Zoom', 'PERSON'),
#  ('$1.8 billion', 'MONEY'),
#  ('the first 10 months of the year', 'DATE'),
#  ('last year', 'DATE'),
#  ('$1.8 billion', 'MONEY'),
#  ('the first 10 months of the year', 'DATE'),
#  ('last year', 'DATE'),
#  ('2020', 'DATE'),
#  ('DeFi', 'PERSON'),
#  ('CipherTrace', 'ORG'),
#  ('Reuters India', 'ORG'),
#  ('Microsoft', 'ORG'),
#  ('Ukraine', 'GPE'),
#  ('nine years', 'DATE'),
#  ('more than $10 million', 'MONEY'),
#  ('Microsoft', 'ORG'),
#  ('Ars Technica', 'PERSON'),
#  ('2016 to 2018', 'DATE'),
#  ('Volodymyr Kvashuk', 'PRODUCT'),
#  ('Microsoft', 'ORG'),
#  ('UK', 'GPE'),
#  ('the Financial Conduct Authority', 'ORG'),
#  ('FCA', 'ORG'),
#  ('PayPal', 'PERSON'),
#  ('Bitcoin', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('PayPal', 'ORG'),
#  ('Dan Schulman', 'PERSON'),
#  ('Reuters', 'ORG'),
#  ('The Ultimate FinTech', 'ORG'),
#  ('Blockchain Bootcamp Bundle', 'ORG'),
#  ('This year', 'DATE'),
#  ('July 4', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('Brock Pierce', 'ORG'),
#  ('October 9', 'DATE'),
#  ('around 50,000', 'CARDINAL'),
#  ('Chinese', 'NORP'),
#  ('digital yuan', 'ORG'),
#  ('The last week', 'DATE'),
#  ('2020', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Biden', 'LOC'),
#  ('Democratic', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('The last week', 'DATE'),
#  ('2020', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Biden', 'LOC'),
#  ('Democratic', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('The last week', 'DATE'),
#  ('2020', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Biden', 'LOC'),
#  ('Democratic', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('China', 'GPE'),
#  ('Sunday', 'DATE'),
#  ('digital yuan', 'ORG'),
#  ('George Floyd', 'PERSON'),
#  ('Breonna Taylor', 'PERSON'),
#  ('Americans', 'NORP'),
#  ('the United States', 'GPE'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('PayPal', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum', 'GPE'),
#  ('Bitcoin Cash', 'GPE'),
#  ('Litecoin', 'PERSON'),
#  ('Bitcoin', 'GPE'),
#  ('PayPal', 'PRODUCT'),
#  ('Reuters', 'ORG'),
#  ('China', 'GPE'),
#  ('around $300 million', 'MONEY'),
#  ('PBOC', 'ORG'),
#  ('Reuters', 'ORG'),
#  ('Jeffrey Gundlach', 'PERSON'),
#  ('DoubleLine', 'ORG'),
#  ('Monday', 'DATE'),
#  ('30-year', 'DATE'),
#  ('Treasury', 'ORG'),
#  ('Jeffrey Gundlach', 'PERSON'),
#  ('DoubleLine', 'ORG'),
#  ('Monday', 'DATE'),
#  ('30-year', 'DATE'),
#  ('Treasury', 'ORG'),
#  ('Twitter Inc', 'ORG'),
#  ('Florida', 'GPE'),
#  ('July', 'DATE'),
#  ('Wednesday', 'DATE'),
#  ('bitcoin', 'GPE'),
#  ('about two years', 'DATE'),
#  ('Capcom', 'ORG'),
#  ('US', 'GPE'),
#  ('Iranian', 'NORP'),
#  ('week', 'DATE'),
#  ('Amazon', 'ORG'),
#  ('Prime Day', 'DATE'),
#  ('One', 'CARDINAL'),
#  ('the Ledger Nano S', 'WORK_OF_ART'),
#  ('39.99', 'MONEY'),
#  ('Amazon', 'ORG'),
#  ('Raoul Pal', 'PERSON'),
#  ('Iranian', 'NORP'),
#  ('U.S.', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('bitcoin', 'GPE'),
#  ('Russian', 'NORP'),
#  ('135 million', 'CARDINAL'),
#  ('$157 million', 'MONEY'),
#  ('Monday', 'DATE'),
#  ('Alexander Vinnik', 'PERSON'),
#  ('the United States', 'GPE'),
#  ('Russia', 'GPE'),
#  ('up to ten years', 'DATE'),
#  ('Paris', 'GPE'),
#  ('Demystify AI', 'GPE'),
#  ('li', 'PERSON'),
#  ('Fairlead Strategies', 'ORG'),
#  ('Katie Stockton.</li', 'PERSON'),
#  ('Tuesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('$1.8 billion', 'MONEY'),
#  ('the first 10 months of the year', 'DATE'),
#  ('last year', 'DATE'),
#  ('Twitter Inc', 'ORG'),
#  ('Florida', 'GPE'),
#  ('July', 'DATE'),
#  ('Wednesday', 'DATE'),
#  ('Amy Castor', 'PERSON'),
#  ('David Gerard', 'PERSON'),
#  ('at least 2013', 'CARDINAL'),
#  ('Wednesday night', 'TIME'),
#  ('less than one week', 'DATE'),
#  ('the United States', 'GPE'),
#  ('U.S.', 'GPE'),
#  ('Twitter', 'ORG'),
#  ('11%', 'PERCENT'),
#  ('third-quarter', 'DATE'),
#  ('Hackaday', 'PERSON'),
#  ('Mike Drew', 'PERSON'),
#  ('PayPal Holdings Inc.', 'ORG'),
#  ('PayPal Holdings Inc <PYPL.O', 'ORG'),
#  ('quarterly', 'DATE'),
#  ('Monday', 'DATE'),
#  ('current-quarter', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('week', 'DATE'),
#  ('March', 'DATE'),
#  ('Federal Reserve', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('Democrat', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('U.S.', 'GPE'),
#  ('Saturday', 'DATE'),
#  ('Donald Trump', 'PERSON'),
#  ('Democrat', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('U.S.', 'GPE'),
#  ('Saturday', 'DATE'),
#  ('Donald Trump', 'PERSON'),
#  ('Olga Kharif / Bloomberg', 'PERSON'),
#  ('1B+', 'MONEY'),
#  ('bitcoin', 'GPE'),
#  ('Tuesday', 'DATE'),
#  ('the Silk Road', 'FAC'),
#  ('Justice Department', 'ORG'),
#  ('Tuesday', 'DATE'),
#  ('7%', 'PERCENT'),
#  ('Bitcoin', 'GPE'),
#  ('Bitcoin', 'GPE'),
#  ('BTC', 'ORG'),
#  ('15,500', 'MONEY'),
#  ('8 percent', 'PERCENT'),
#  ('the last 24 hours', 'TIME'),
#  ('2018', 'DATE'),
#  ('November 3', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('VastaamoThe', 'ORG'),
#  ('tens of thousands', 'CARDINAL'),
#  ('Finland', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('third', 'ORDINAL'),
#  ('Square Inc.', 'ORG'),
#  ('the third quarter', 'DATE'),
#  ('October', 'DATE'),
#  ('a year earlier', 'DATE')]

# %% [markdown]
# ## Ethereum NER

# %%
ethereum_concat = ethereum_df['description'].str.cat(sep=', ')

# %%
eth_ner = nlp(ethereum_concat)
eth_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has partnered with cryptocurrency company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paxos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to launch a new service.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  users in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will soon be able to buy, hold and sell cryptocurrencies. More countries are coming soon.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  plans to support
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# …, Breitling is partnering with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arianee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to issue a new kind of certificates of authenticity for its luxury watches. Instead of relying on physical certificates, the watchmaker gives you a unique digital passport that certifies the origin of the watch. Behind the…,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is joining the cryptocurrency industry with support for bitcoin and other digital currencies, making the digital payments company
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most significant adopters of the technology to date.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  plans to extend support to its money-sending
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     app Ve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# …, Summary List Placement</br></br>Portions of the global economy melted down in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but an emerging asset class seems to have reinforced its staying power amid the chaos.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayscale Investments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the world's largest digital-currency asset manager, notched its largest-e…,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's central bank launches digital currency project
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align

# %%
from pprint import pprint
pprint([(X.text, X.label_) for X in eth_ner.ents])
# Out:
# [('PayPal', 'ORG'),
#  ('Paxos', 'ORG'),
#  ('PayPal', 'PRODUCT'),
#  ('U.S.', 'GPE'),
#  ('PayPal', 'PRODUCT'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum', 'GPE'),
#  ('Bitcoin Cash', 'PERSON'),
#  ('Lite', 'PERSON'),
#  ('Arianee', 'PERSON'),
#  ('PayPal', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('PayPal', 'PRODUCT'),
#  ('app Ve', 'ORG'),
#  ('2020', 'DATE'),
#  ('Grayscale Investments', 'ORG'),
#  ('Australia', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('UK', 'GPE'),
#  ('2020', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('morning', 'TIME'),
#  ('Elon Musk', 'WORK_OF_ART'),
#  ('Twitter', 'ORG'),
#  ('Quibi', 'ORG'),
#  ('PayPal', 'PRODUCT'),
#  ('Netflix', 'PERSON'),
#  ('Daily Crunch', 'WORK_OF_ART'),
#  ('October 21, 2020', 'DATE'),
#  ('app', 'ORG'),
#  ('Jeffrey Katzenberg', 'PERSON'),
#  ('PayPal', 'NORP'),
#  ('Reuters', 'ORG'),
#  ('Amazon', 'ORG'),
#  ('Prime Day', 'DATE'),
#  ('One', 'CARDINAL'),
#  ('the Ledger Nano S', 'WORK_OF_ART'),
#  ('39.99', 'MONEY'),
#  ('Amazon', 'ORG'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('PayPal Holdings Inc <PYPL.O', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('PayPal Holdings Inc', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Tim Copeland / Decrypt', 'PERSON'),
#  ('Ethereum Foundation', 'ORG'),
#  ('Ethereum 2.0', 'ORG'),
#  ('December 1', 'DATE'),
#  ('1.0', 'CARDINAL'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('PayPal', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum', 'GPE'),
#  ('Bitcoin Cash', 'GPE'),
#  ('Litecoin', 'PERSON'),
#  ('Omkar Godbole / CoinDesk', 'PERSON'),
#  ('Glassnode', 'PERSON'),
#  ('57.5', 'MONEY'),
#  ('October', 'DATE'),
#  ('September', 'DATE'),
#  ('166.4', 'MONEY'),
#  ('DeFi', 'LOC'),
#  ('Earlier this year', 'DATE'),
#  ('CoinDesk', 'PERSON'),
#  ('1', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('November 9', 'DATE'),
#  ('12', 'CARDINAL'),
#  ('CWT', 'ORG'),
#  ('CWT', 'ORG'),
#  ('Vitalik', 'PERSON'),
#  ('a few years ago', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('PayPal', 'PERSON'),
#  ('today', 'DATE'),
#  ('PayPal', 'PRODUCT'),
#  ('PayPal', 'PRODUCT'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum', 'GPE'),
#  ('Bitcoin Cash', 'PERSON'),
#  ('Litecoin', 'PERSON'),
#  ('Amazon', 'ORG'),
#  ('Prime Day', 'DATE'),
#  ('One', 'CARDINAL'),
#  ('the Ledger Nano S', 'WORK_OF_ART'),
#  ('39.99', 'MONEY'),
#  ('Amazon', 'ORG'),
#  ('PayPal Holdings Inc.', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum (ETH', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('$43 billion', 'MONEY'),
#  ('4%', 'PERCENT'),
#  ('4 hours', 'TIME'),
#  ('one', 'CARDINAL'),
#  ('Python', 'ORG'),
#  ('Ethereum', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('ETH', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('the Associated Press', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('13,000', 'MONEY'),
#  ('a week ago', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('weekly', 'DATE'),
#  ('mid-2019', 'DATE'),
#  ('14000', 'DATE'),
#  ('weekly', 'DATE'),
#  ('Solidity', 'ORG'),
#  ('Smartereum', 'ORG'),
#  ('Bitcoin', 'GPE'),
#  ('12,000', 'MONEY'),
#  ('first', 'ORDINAL'),
#  ('September', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('DeFi', 'FAC'),
#  ('Bitcoin', 'GPE'),
#  ('32 ether', 'QUANTITY'),
#  ('ETH', 'ORG'),
#  ('Eth 2.0.', 'PERSON'),
#  ('WKX and Ethereum', 'ORG'),
#  ('Ethereum', 'GPE'),
#  ('2', 'CARDINAL'),
#  ('Zinken', 'ORG'),
#  ('Medalla', 'PERSON'),
#  ('INX Limited', 'PERSON'),
#  ('Ethereum', 'ORG'),
#  ('last month', 'DATE'),
#  ('U.S.', 'GPE'),
#  ('Openfinance Securities', 'ORG'),
#  ('Vitalik Buterin', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Breitling', 'GPE'),
#  ('first', 'ORDINAL'),
#  ('Ethereum', 'ORG'),
#  ('digital', 'ORG'),
#  ('WZEC', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('Tokensoft', 'PERSON'),
#  ('Anchorage', 'PERSON'),
#  ('today', 'DATE'),
#  ('Eth', 'GPE'),
#  ('Beacon', 'PRODUCT'),
#  ('Ethereum 2.0', 'ORG'),
#  ('Pioneers', 'GPE'),
#  ('Ethereum 2.0', 'ORG'),
#  ('Ethereum 2.0’s', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('October', 'DATE'),
#  ('DeFi', 'PERSON'),
#  ('Gemini', 'PERSON'),
#  ('Filecoin', 'PERSON'),
#  ('FIL', 'ORG'),
#  ('bitcoin', 'GPE'),
#  ('UK', 'GPE'),
#  ('the Financial Conduct Authority', 'ORG'),
#  ('FCA', 'ORG'),
#  ('CoinDesk', 'PERSON'),
#  ('Christine Kim', 'PERSON'),
#  ('Michael J. Casey', 'PERSON'),
#  ('Aaron Stanley', 'PERSON'),
#  ('Ethereum 2.0', 'ORG'),
#  ('next week', 'DATE'),
#  ('PayPal', 'PERSON'),
#  ('Bitcoin', 'GPE'),
#  ('PayPal', 'GPE'),
#  ('Ethereum', 'ORG'),
#  ('ETH', 'ORG'),
#  ('Staked.', 'GPE'),
#  ('Blockchain Bites', 'ORG'),
#  ('Elon Musk', 'ORG'),
#  ('Gigafactory Bitcoin ATM', 'ORG'),
#  ('nearly $1.5 billion', 'MONEY'),
#  ('Bitcoin', 'GPE'),
#  ('two-month', 'DATE'),
#  ('Monday', 'DATE'),
#  ('three-week', 'DATE'),
#  ('Grayscale', 'ORG'),
#  ('Ethereum Trust', 'ORG'),
#  ('SEC', 'ORG'),
#  ('Some $1 million', 'MONEY'),
#  ('DeFi', 'LAW'),
#  ('app', 'ORG'),
#  ('Ethereum Foundation', 'ORG'),
#  ('Danny Ryan', 'PERSON'),
#  ('ConsenSys', 'ORG'),
#  ('Societe Generale', 'ORG'),
#  ("CoinDesk Research's", 'ORG'),
#  ('Monthly Review', 'ORG'),
#  ('October', 'DATE'),
#  ('Bitcoin', 'GPE'),
#  ('Ethereum', 'GPE'),
#  ('Crypto M&A', 'ORG'),
#  ('last year', 'DATE'),
#  ('CFTC', 'ORG'),
#  ('Tarbert', 'PERSON'),
#  ('Filecoin', 'PERSON'),
#  ('11', 'MONEY'),
#  ('CoinDesk’s Markets Daily', 'ORG'),
#  ('January', 'DATE'),
#  ('Berlin', 'GPE'),
#  ('first', 'ORDINAL'),
#  ('July', 'DATE'),
#  ('Ethereum’s 2.0', 'ORG'),
#  ('50k', 'CARDINAL'),
#  ('10%', 'PERCENT'),
#  ('Bitcoin', 'GPE'),
#  ('over $14,000', 'MONEY'),
#  ('more than $100 million', 'MONEY'),
#  ('$750 million', 'MONEY'),
#  ('bitcoin', 'GPE'),
#  ('Friday', 'DATE'),
#  ('bitcoin', 'GPE'),
#  ('Amy Castor', 'PERSON'),
#  ('David Gerard', 'PERSON'),
#  ('at least 2013', 'CARDINAL'),
#  ('The Block Research', 'ORG'),
#  ('monthly', 'DATE'),
#  ('5.3%', 'PERCENT'),
#  ('September', 'DATE'),
#  ('$163.1 billion to $172.2 billion', 'MONEY'),
#  ('$1.7 trillion', 'MONEY'),
#  ('G20', 'ORG'),
#  ('Binance', 'ORG'),
#  ('Binance Smart Chain', 'ORG'),
#  ('DeFi', 'ORG'),
#  ('Edan Yago', 'PERSON'),
#  ('Bitcoin', 'GPE'),
#  ('2020', 'DATE'),
#  ('Securitize', 'PERSON'),
#  ('Tinlake', 'PRODUCT'),
#  ('Centrifuge', 'GPE'),
#  ('DeFi', 'LOC'),
#  ('Michael Sonnenshein', 'PERSON'),
#  ('third', 'ORDINAL'),
#  ('Ocean Protocol', 'ORG'),
#  ('the past year', 'DATE'),
#  ('DeFi', 'FAC'),
#  ('the last nine months', 'DATE'),
#  ('the day', 'DATE'),
#  ('day', 'DATE'),
#  ("DeFi Degens'", 'PERSON'),
#  ('the week', 'DATE'),
#  ('the week', 'DATE'),
#  ('the day', 'DATE'),
#  ('day', 'DATE'),
#  ('More than 90 percent', 'PERCENT'),
#  ('Just 38 percent', 'PERCENT'),
#  ('Kadena', 'ORG'),
#  ('Tuesday', 'DATE'),
#  ('Terra', 'ORG'),
#  ('Terra', 'ORG'),
#  ('Luna', 'PERSON'),
#  ('Kadenswap', 'PERSON'),
#  ('51%', 'PERCENT'),
#  ('the Ethereum Classic', 'LAW'),
#  ("Grayscale's Ethereum Trust", 'ORG'),
#  ('the Securities and Exchange Commission', 'ORG'),
#  ("Grayscale's Ethereum Trust", 'ORG'),
#  ('GBTC', 'ORG'),
#  ('SEC', 'ORG'),
#  ('first', 'ORDINAL')]
